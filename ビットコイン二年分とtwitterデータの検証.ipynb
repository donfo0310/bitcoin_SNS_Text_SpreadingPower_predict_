# %%
#import pandas_datareader.data as web

#import datetime

#nikkei=web.DataReader("NIKKEI225","fred","2017/1/1")

# %%
#from matplotlib import pylab as plt
#plt.plot(nikkei)
#plt.show()

# %%
#start = datetime.datetime(2018, 1, 1)
#end = datetime.datetime(2018, 9, 6)

#stock = web.DataReader(["NIKKEI225", "DJIA"], "fred", start, end)

# %%
#plt.plot(stock)
#plt.show()

# %%
#plt.plot(stock["NIKKEI225"])
#plt.show()

# %%
#plt.plot(stock.index,stock["NIKKEI225"])

# %%
#type(stock.index)

# %%
#stock.index[0]

# %%
import datetime
import poloniex
import pandas as pd
from datetime import time
import pandas as pd
import time
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
#ds = datetime.datetime(2018,1, 1, 0, 0, 0).timestamp()
#de = datetime.datetime(2018,9,6,0,0,0).timestamp()


# poloniex APIの準備
#polo = poloniex.Poloniex()

# 5分間隔（サンプリング間隔300秒）で100日分読み込む
#chart_data = polo.returnChartData('USDT_BTC', period=polo.DAY, start=time.time() - polo.DAY * 800, end=time.time())
#chart_data = polo.returnChartData('USDT_BTC', period=polo.DAY, start=ds, end=de)
#bitprice=pd.DataFrame(chart_data)

# %%
#time.time() - polo.DAY * 800
# Out:
# 1467119892.529357

# %%
import seaborn as sns
rcParams['figure.figsize'] = 15, 6
#plt.plot(pd.to_numeric(bitprice['close'], errors='coerce').fillna(0, downcast='infer'))
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6c089e8aaaae> in <module>()
#       1 import seaborn as sns
# ----> 2 rcParams['figure.figsize'] = 15, 6
#       3 #plt.plot(pd.to_numeric(bitprice['close'], errors='coerce').fillna(0, downcast='infer'))
#       4 #plt.show()
#
# NameError: name 'rcParams' is not defined

# %%
import pandas as pd
#df = pd.read_csv("bit-PN-data-re.csv")
df=pd.read_csv('w2v-svm-PN-jyuuhuku-sin.csv')

# %%
df = pd.read_csv("favo1.csv")

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df=df.drop(882,axis=0)

# %%
plt.plot(df["sum"])
plt.show()

# %%
#df.index=pd.to_datetime(df['day'])
df=df.drop('day',axis=1)

# %%
df
# Out:
#             day        PN
# 0    2016-01-01  2.000000
# 1    2016-01-02  2.051282
# 2    2016-01-03  2.021505
# 3    2016-01-04  1.982759
# 4    2016-01-05  1.963964
# 5    2016-01-06  2.047945
# 6    2016-01-07  2.126126
# 7    2016-01-08  1.948718
# 8    2016-01-09  1.942029
# 9    2016-01-10  1.892308
# 10   2016-01-11  2.101266
# 11   2016-01-12  2.065789
# 12   2016-01-13  1.852174
# 13   2016-01-14  2.025862
# 14   2016-01-15  2.028249
# 15   2016-01-16  1.889571
# 16   2016-01-17  2.112903
# 17   2016-01-18  2.125000
# 18   2016-01-19  1.935780
# 19   2016-01-20  1.958042
# 20   2016-01-21  1.908497
# 21   2016-01-22  1.961538
# 22   2016-01-23  2.097561
# 23   2016-01-24  2.010417
# 24   2016-01-25  1.962121
# 25   2016-01-26  2.008850
# 26   2016-01-27  1.989474
# 27   2016-01-28  2.038835
# 28   2016-01-29  2.056338
# 29   2016-01-30  1.961538
# ..          ...       ...
# 853  2018-05-03  2.116631
# 854  2018-05-04  2.170416
# 855  2018-05-05  2.111620
# 856  2018-05-06  2.045056
# 857  2018-05-07  2.065990
# 858  2018-05-08  2.101806
# 859  2018-05-09  2.092956
# 860  2018-05-10  2.036505
# 861  2018-05-11  2.062056
# 862  2018-05-12  2.083603
# 863  2018-05-13  2.065006
# 864  2018-05-14  2.071947
# 865  2018-05-15  2.051587
# 866  2018-05-16  2.036170
# 867  2018-05-17  2.053855
# 868  2018-05-18  2.047837
# 869  2018-05-19  2.055186
# 870  2018-05-20  2.092750
# 871  2018-05-21  2.107191
# 872  2018-05-22  2.076676
# 873  2018-05-23  2.040865
# 874  2018-05-24  2.073854
# 875  2018-05-25  2.078784
# 876  2018-05-26  2.086640
# 877  2018-05-27  2.103007
# 878  2018-05-28  2.103659
# 879  2018-05-29  2.047036
# 880  2018-05-30  2.035160
# 881  2018-05-31  2.056370
# 882  2018-06-01  2.062185
#
# [883 rows x 2 columns]

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d')
data = pd.read_csv('bit-PN-data-re.csv', index_col='day', date_parser=dateparse, dtype='float')
del data["Unnamed: 0"]
data.head()
# Out:
#                  sum
# day
# 2016-03-01 -0.305511
# 2016-02-29 -0.375559
# 2016-02-28 -0.391223
# 2016-02-27 -0.373816
# 2016-02-26 -0.377355

# %%
#plt.plot(data)
data[data['sum']<-8]
# Out:
#                   sum
# day
# 2018-04-27 -11.726484

# %%
data['2018-04-27']=(data['2018-04-26']+data['2018-04-28'])/2.0

# %%
data.plot()

# %%
data=data.sort_index()

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [sum]
# Index: []

# %%
#data

# %%
import pandas as pd
import datetime
import poloniex
from datetime import time
import time
from matplotlib import pylab as plt
import seaborn as sns
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6 
from scipy import stats
import statsmodels.api as sm
import numpy as np
from statsmodels.tsa.api import VAR, DynamicVAR
rcParams['figure.figsize'] = 15, 6

# %%
data1 = pd.read_csv('BTC_JPY.csv')
#data1['Date','Price']

# %%
data=df

# %%
#dat=data1['Price'].interpolate()#前後の値で線形補間
#dat=dat.str.replace(',', '.')
data=pd.read_csv('w2v-svm-PN-sin.csv')

# %%
#dat=data1['Price'].str.replace(',','')
#dat=dat.astype(float)
data=data.drop('Unnamed: 0',axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-86ba3fe5818a> in <module>()
#       1 #dat=data1['Price'].str.replace(',','')
#       2 #dat=dat.astype(float)
# ----> 3 data=data.drop('Unnamed: 0',axis=1)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3739             if errors != 'ignore':
#    3740                 raise ValueError('labels %s not contained in axis' %
# -> 3741                                  labels[mask])
#    3742             indexer = indexer[~mask]
#    3743         return self.delete(indexer)
#
# ValueError: labels ['Unnamed: 0'] not contained in axis

# %%
#dat=dat.interpolate()

# %%
rcParams['figure.figsize'] = 15, 6
#dat

# %%
#dat.plot()

# %%
#data.plot()

# %%
#pd.to_datetime(data1['Date'])

# %%
#dat['day']=pd.to_datetime(data1['Date'])
#dat
data
# Out:
#             day        PN
# 0    2016-01-01  2.000000
# 1    2016-01-02  2.051282
# 2    2016-01-03  2.021505
# 3    2016-01-04  1.982759
# 4    2016-01-05  1.963964
# 5    2016-01-06  2.047945
# 6    2016-01-07  2.126126
# 7    2016-01-08  1.948718
# 8    2016-01-09  1.942029
# 9    2016-01-10  1.892308
# 10   2016-01-11  2.101266
# 11   2016-01-12  2.065789
# 12   2016-01-13  1.852174
# 13   2016-01-14  2.025862
# 14   2016-01-15  2.028249
# 15   2016-01-16  1.889571
# 16   2016-01-17  2.112903
# 17   2016-01-18  2.125000
# 18   2016-01-19  1.935780
# 19   2016-01-20  1.958042
# 20   2016-01-21  1.908497
# 21   2016-01-22  1.961538
# 22   2016-01-23  2.097561
# 23   2016-01-24  2.010417
# 24   2016-01-25  1.962121
# 25   2016-01-26  2.008850
# 26   2016-01-27  1.989474
# 27   2016-01-28  2.038835
# 28   2016-01-29  2.056338
# 29   2016-01-30  1.961538
# ..          ...       ...
# 853  2018-05-03  2.116631
# 854  2018-05-04  2.170416
# 855  2018-05-05  2.111620
# 856  2018-05-06  2.045056
# 857  2018-05-07  2.065990
# 858  2018-05-08  2.101806
# 859  2018-05-09  2.092956
# 860  2018-05-10  2.036505
# 861  2018-05-11  2.062056
# 862  2018-05-12  2.083603
# 863  2018-05-13  2.065006
# 864  2018-05-14  2.071947
# 865  2018-05-15  2.051587
# 866  2018-05-16  2.036170
# 867  2018-05-17  2.053855
# 868  2018-05-18  2.047837
# 869  2018-05-19  2.055186
# 870  2018-05-20  2.092750
# 871  2018-05-21  2.107191
# 872  2018-05-22  2.076676
# 873  2018-05-23  2.040865
# 874  2018-05-24  2.073854
# 875  2018-05-25  2.078784
# 876  2018-05-26  2.086640
# 877  2018-05-27  2.103007
# 878  2018-05-28  2.103659
# 879  2018-05-29  2.047036
# 880  2018-05-30  2.035160
# 881  2018-05-31  2.056370
# 882  2018-06-01  2.062185
#
# [883 rows x 2 columns]

# %%
data1=data1.loc[:,['Date','Price']]

# %%
data1['Date']=pd.to_datetime(data1['Date'])

# %%
data1.index=data1['Date']

# %%
a=pd.concat([data,data1],axis=1)

# %%
#a=pd.concat([df,data1],axis=1)
data1=data1.sort_index()
data1.head()
# Out:
#                  Date   Price
# Date
# 2016-01-01 2016-01-01  52,048
# 2016-01-02 2016-01-02  51,802
# 2016-01-03 2016-01-03  51,489
# 2016-01-04 2016-01-04  51,392
# 2016-01-05 2016-01-05  52,249

# %%
a
# Out:
#                    day        PN       Date      Price
# 2016-01-01  2016-01-01  2.000000 2016-01-01     52,048
# 2016-01-02  2016-01-02  2.051282 2016-01-02     51,802
# 2016-01-03  2016-01-03  2.021505 2016-01-03     51,489
# 2016-01-04  2016-01-04  1.982759 2016-01-04     51,392
# 2016-01-05  2016-01-05  1.963964 2016-01-05     52,249
# 2016-01-06  2016-01-06  2.047945 2016-01-06     51,422
# 2016-01-07  2016-01-07  2.126126 2016-01-07     54,350
# 2018-05-27  2018-05-27  2.103007 2018-05-27    806,530
# 2018-05-28  2018-05-28  2.103659 2018-05-28    789,279
# 2018-05-29  2018-05-29  2.047036 2018-05-29    828,699
# 2018-05-30  2018-05-30  2.035160 2018-05-30    818,946
# 2018-05-31  2018-05-31  2.056370 2018-05-31    824,313
# 2018-06-01  2018-06-01  2.062185 2018-06-01    833,961
#
# [883 rows x 4 columns]

# %%
#a[a.index!=a['Date']]
data.index=pd.to_datetime(data['day'])
data=data.sort_index()
data.head()
# Out:
#                    day        PN
# day
# 2016-01-01  2016-01-01  2.000000
# 2016-01-02  2016-01-02  2.051282
# 2016-01-03  2016-01-03  2.021505
# 2016-01-04  2016-01-04  1.982759
# 2016-01-05  2016-01-05  1.963964

# %%
a=a.drop('Date',axis=1)
a=a.drop('day',axis=1)
a.head()
# Out:
#                   PN   Price
# 2016-01-01  2.000000  52,048
# 2016-01-02  2.051282  51,802
# 2016-01-03  2.021505  51,489
# 2016-01-04  1.982759  51,392
# 2016-01-05  1.963964  52,249

# %%
a.plot()

# %%
#a.iat[1,1]

# %%
a['Price']=a['Price'].str.replace(',','')
a['Price']=a['Price'].astype(float)
a=a.interpolate()

# %%
a.index=pd.to_datetime(a['Unnamed: 0'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2521             try:
# -> 2522                 return self._engine.get_loc(key)
#    2523             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-b161bd58d9e4> in <module>()
# ----> 1 a.index=pd.to_datetime(a['Unnamed: 0'])
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3836
#    3837             if not isna(item):
# -> 3838                 loc = self.items.get_loc(item)
#    3839             else:
#    3840                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2522                 return self._engine.get_loc(key)
#    2523             except KeyError:
# -> 2524                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2525
#    2526         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 0'

# %%
a=a.drop('Unnamed: 0',axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-a7f5ea7a77b7> in <module>()
# ----> 1 a=a.drop('Unnamed: 0',axis=1)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3739             if errors != 'ignore':
#    3740                 raise ValueError('labels %s not contained in axis' %
# -> 3741                                  labels[mask])
#    3742             indexer = indexer[~mask]
#    3743         return self.delete(indexer)
#
# ValueError: labels ['Unnamed: 0'] not contained in axis

# %%
a.plot()

# %%
a
# Out:
#                   PN      Price
# 2016-01-01  2.000000    52048.0
# 2016-01-02  2.051282    51802.0
# 2016-01-03  2.021505    51489.0
# 2016-01-04  1.982759    51392.0
# 2016-01-05  1.963964    52249.0
# 2016-01-06  2.047945    51422.0
# 2016-01-07  2.126126    54350.0
# 2016-01-08  1.948718    53926.0
# 2016-01-09  1.942029    52789.0
# 2016-01-10  1.892308    52145.0
# 2016-01-11  2.101266    52739.0
# 2016-01-12  2.065789    50981.0
# 2016-01-13  1.852174    50175.0
# 2016-01-14  2.025862    50042.0
# 2016-01-15  2.028249    47352.0
# 2016-01-16  1.889571    45893.0
# 2016-01-17  2.112903    45933.0
# 2016-01-18  2.125000    45976.0
# 2016-01-19  1.935780    44565.0
# 2016-01-20  1.958042    49500.0
# 2016-01-21  1.908497    50980.0
# 2016-01-22  1.961538    45175.0
# 2016-01-23  2.097561    44893.0
# 2016-01-24  2.010417    47101.0
# 2016-01-25  1.962121    44882.0
# 2016-01-26  2.008850    46351.0
# 2016-01-27  1.989474    46729.0
# 2016-01-28  2.038835    44839.0
# 2016-01-29  2.056338    45248.0
# 2016-01-30  1.961538    46694.0
# ...              ...        ...
# 2018-05-03  2.116631  1070560.0
# 2018-05-04  2.170416  1050635.0
# 2018-05-05  2.111620  1056467.0
# 2018-05-06  2.045056  1057802.0
# 2018-05-07  2.065990  1023860.0
# 2018-05-08  2.101806  1010974.0
# 2018-05-09  2.092956  1007039.0
# 2018-05-10  2.036505   993113.0
# 2018-05-11  2.062056   973212.0
# 2018-05-12  2.083603   954681.0
# 2018-05-13  2.065006   977325.0
# 2018-05-14  2.071947   976336.0
# 2018-05-15  2.051587   940384.0
# 2018-05-16  2.036170   921471.0
# 2018-05-17  2.053855   895177.0
# 2018-05-18  2.047837   917200.0
# 2018-05-19  2.055186   904128.0
# 2018-05-20  2.092750   945392.0
# 2018-05-21  2.107191   935786.0
# 2018-05-22  2.076676   892590.0
# 2018-05-23  2.040865   842477.0
# 2018-05-24  2.073854   834113.0
# 2018-05-25  2.078784   816057.0
# 2018-05-26  2.086640   808678.0
# 2018-05-27  2.103007   806530.0
# 2018-05-28  2.103659   789279.0
# 2018-05-29  2.047036   828699.0
# 2018-05-30  2.035160   818946.0
# 2018-05-31  2.056370   824313.0
# 2018-06-01  2.062185   833961.0
#
# [883 rows x 2 columns]

# %%
a=pd.read_csv('bit-kyokusei-re.csv')

# %%
import scipy.stats as zscore

# %%
import scipy.stats as zscore
b=zscore.zscore(a,axis=0)
#b=pd.to_datetime(b)
#b.plot()

# %%
b=pd.DataFrame(data=b,  columns=['sum','price'], dtype='float')
b.plot()

# %%
#ここからグレンジャー因果性の測定
a.to_csv('bit-kyokusei-re.csv')

# %%
a.to_csv('favo-RT>1.csv')

# %%
def min_max_normalization(x):
    x_min = x.min()
    x_max = x.max()
    x_mean = x.mean()
    x_norm = (x - x_min) / ( x_max - x_min)
    return x_norm

#ad=min_max_normalization(a)

# %%
b['sum'].plot()

# %%
ad = b - b.shift(1)

# %%
ad.plot()

# %%
ad=ad.dropna()

# %%
#l=min_max_normalization(l)
#l.plot()
ad
# Out:
#           sum     price
# 1    2.536970 -0.000519
# 2    0.947774 -0.000661
# 3   -1.120096 -0.000205
# 4    1.425577  0.001809
# 5   -1.093696 -0.001746
# 6   -0.865259  0.006180
# 7    1.529020 -0.000895
# 8   -0.588333 -0.002400
# 9   -2.979380 -0.001359
# 10   3.585493  0.001254
# 11  -1.838754 -0.003711
# 12  -0.668127 -0.001701
# 13   2.026840 -0.000281
# 14  -0.350219 -0.005678
# 15   1.050569 -0.003079
# 16   1.172403  0.000084
# 17  -1.037126  0.000091
# 18  -0.622276 -0.002978
# 19  -1.680144  0.010416
# 20   1.937637  0.003124
# 21   1.938773 -0.012252
# 22  -1.517421 -0.000595
# 23  -3.550887  0.004660
# 24   2.042340 -0.004684
# 25   0.255293  0.003101
# 26   1.148816  0.000798
# 27   1.048919 -0.003989
# 28   0.413211  0.000863
# 29  -3.903365  0.003052
# 30   4.941600 -0.005382
# ..        ...       ...
# 853  0.224457  0.115330
# 854  0.775824 -0.042055
# 855 -0.753540  0.012309
# 856 -0.078109  0.002818
# 857 -0.064145 -0.071639
# 858  0.239554 -0.027198
# 859 -0.296075 -0.008305
# 860 -0.142226 -0.029393
# 861 -0.288434 -0.042004
# 862 -0.022362 -0.039112
# 863  0.220051  0.047793
# 864 -0.092661 -0.002087
# 865 -0.311690 -0.075882
# 866  0.316970 -0.039919
# 867 -0.154262 -0.055497
# 868  0.134391  0.046483
# 869  0.642551 -0.027590
# 870  0.035951  0.087094
# 871 -0.231164 -0.020275
# 872 -0.768271 -0.091171
# 873  0.371043 -0.105771
# 874 -0.074302 -0.017653
# 875  0.482425 -0.038110
# 876 -0.331945 -0.015574
# 877  0.503539 -0.004534
# 878  0.506164 -0.036411
# 879 -0.840741  0.083202
# 880 -0.541955 -0.020585
# 881  0.609819  0.011328
# 882  0.725771  0.020363
#
# [882 rows x 2 columns]

# %%
l=ad.values
l2=l-l.mean()
l=l2/l2.std()
l=min_max_normalization(l)
#l.plot()

# %%
l=pd.DataFrame(data=l,  columns=['sum','price'], dtype='float')
l.plot()

# %%
#l

# %%
ad.plot()

# %%
var=[]
for i in range(11):
    #var.append(VAR(l[['price','sum']]).fit(maxlags=i))
    var.append(VAR(l[['sum','price']]).fit(maxlags=i))

# %%
#ad.plot()
var=[]
for i in range(11):
     var.append(VAR(ad[['sum','price']]).fit(maxlags=i))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:221: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:221: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:221: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:221: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:221: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:221: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:221: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:221: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:221: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:221: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:221: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
#ad[ad['Price']>2]
var
# Out:
# [<statsmodels.tsa.vector_ar.var_model.VARResultsWrapper at 0x115c58198>,
#  <statsmodels.tsa.vector_ar.var_model.VARResultsWrapper at 0x115937b00>,
#  <statsmodels.tsa.vector_ar.var_model.VARResultsWrapper at 0x115c43da0>,
#  <statsmodels.tsa.vector_ar.var_model.VARResultsWrapper at 0x115a0f0f0>,
#  <statsmodels.tsa.vector_ar.var_model.VARResultsWrapper at 0x115e16cc0>,
#  <statsmodels.tsa.vector_ar.var_model.VARResultsWrapper at 0x115e39080>,
#  <statsmodels.tsa.vector_ar.var_model.VARResultsWrapper at 0x115e39c50>,
#  <statsmodels.tsa.vector_ar.var_model.VARResultsWrapper at 0x115e4ee48>,
#  <statsmodels.tsa.vector_ar.var_model.VARResultsWrapper at 0x115e30fd0>,
#  <statsmodels.tsa.vector_ar.var_model.VARResultsWrapper at 0x115e306a0>,
#  <statsmodels.tsa.vector_ar.var_model.VARResultsWrapper at 0x11578c630>]

# %%
#l

# %%
aic=[]
for i in range(11):
    aic.append(var[i].aic)
pd.Series(aic,index=range(11),name='AIC')
# Out:
# 0    -13.141590
# 1    -13.291053
# 2    -13.349204
# 3    -13.377785
# 4    -13.394175
# 5    -13.412098
# 6    -13.417917
# 7    -13.431265
# 8    -13.429609
# 9    -13.429661
# 10   -13.428677
# Name: AIC, dtype: float64

# %%
names=['value','price']
stat=[]
pval=[]
null=[]
for i in range(2):
    for j in range(2):
        if i!=j:
            test=var[2].test_causality(i,j,kind='f',signif=0.05)
            stat.append(test.test_statistic.round(1))
            pval.append(test.pvalue.round(3))
            null.append('%s->%s'%(names[j],names[i]))
        else:
            pass
pd.DataFrame({'Statistics':stat,'P_value':pval},index=null,columns=['Statistics','P_value']).T
# Out:
#             price->value  value->price
# Statistics         1.500         4.300
# P_value            0.231         0.014

# %%
names=['value','price']
#names=['price','value']
stat=[]
pval=[]
null=[]
for h in range(1,10):
    for i in range(2):
        for j in range(2):
            if i!=j:
                test=var[h].test_causality(i,j,kind='f',signif=0.05)
                stat.append(test.test_statistic.round(1))
                pval.append(test.pvalue.round(3))
                null.append('%s->%s'%(names[j],names[i]))
            else:
                pass
    print(str(h)+"  lag")
    print(pd.DataFrame({'Statistics':stat,'P_value':pval},index=null,columns=['Statistics','P_value']).T)
    print("--------------------------------------")
    stat=[]
    pval=[]
    null=[]
# Out:
# 1  lag
#             price->value  value->price
# Statistics         5.100         0.000
# P_value            0.024         0.984
# --------------------------------------
# 2  lag
#             price->value  value->price
# Statistics         4.200         1.200
# P_value            0.016         0.312
# --------------------------------------
# 3  lag
#             price->value  value->price
# Statistics         4.100         0.700
# P_value            0.007         0.525
# --------------------------------------
# 4  lag
#             price->value  value->price
# Statistics         2.900         0.400
# P_value            0.019         0.806
# --------------------------------------
# 5  lag
#             price->value  value->price
# Statistics         2.400         0.600
# P_value            0.036         0.735
# --------------------------------------
# 6  lag
#             price->value  value->price
# Statistics         2.200         0.500
# P_value            0.042         0.825
# --------------------------------------
# 7  lag
#             price->value  value->price
# Statistics         2.300         0.300
# P_value            0.024         0.945
# --------------------------------------
# 8  lag
#             price->value  value->price
# Statistics         2.000         0.500
# P_value            0.043         0.886
# --------------------------------------
# 9  lag
#             price->value  value->price
# Statistics         1.600         0.500
# P_value            0.098         0.901
# --------------------------------------

# %%
names=['value','price']
stat=[]
pval=[]
null=[]
#for b in range(1,10):
for i in range(2):
    for j in range(2):
            if i!=j:
                test=var[2].test_causality(i,j,kind='f',signif=0.05)
                stat.append(test.test_statistic.round(1))
                pval.append(test.pvalue.round(3))
                null.append('%s->%s'%(names[j],names[i]))
            else:
                pass
    print(pd.DataFrame({'Statistics':stat,'P_value':pval},index=null,columns=['Statistics','P_value']).T)
# Out:
#             price->value
# Statistics         1.500
# P_value            0.231
#             price->value  value->price
# Statistics         1.500         4.300
# P_value            0.231         0.014

# %%
names=['value','price']
stat=[]
pval=[]
null=[]
for i in range(2):
    for j in range(2):
        if i!=j:
            test=var[10].test_causality(i,j,kind='f',signif=0.05)
            stat.append(test.test_statistic.round(1))
            pval.append(test.pvalue.round(3))
            null.append('%s->%s'%(names[j],names[i]))
        else:
            pass
pd.DataFrame({'Statistics':stat,'P_value':pval},index=null,columns=['Statistics','P_value']).T
# Out:
#             price->value  value->price
# Statistics         0.300         0.800
# P_value            0.991         0.655

# %%
import datetime
import poloniex
import pandas as pd
from datetime import time
import pandas as pd
import time
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#LSTMによる予測

from keras.models import Sequential  
from keras.layers.core import Dense, Activation  
from keras.layers.recurrent import LSTM
#_loaddata1は二変数用　_loaddataは一変数用

def _load_data1(data, n_prev=3):
    docX, docY = [], []
    for i in range(len(data)-n_prev):
        #print(i)
        docX.append(data.iloc[i:i+n_prev].as_matrix())
        docY.append(data['price'].iloc[i+n_prev])#data['price']
    alsX = np.array(docX)
    alsY = np.array(docY)
    return alsX, alsY

def _load_data(data, n_prev=3):
    docX, docY = [], []
    for i in range(len(data)-n_prev):
        #print(i)
        docX.append(data.iloc[i:i+n_prev].as_matrix())
        docY.append(data.iloc[i+n_prev])#data['price']
    alsX = np.array(docX)
    alsY = np.array(docY)
    return alsX, alsY

def train_test_split(df, test_size=0.2, n_prev=3):
    ntrn = round(len(df) * (1 - test_size))
    ntrn = int(ntrn)
    #print("a")
    X_train, y_train = _load_data1(df.iloc[0:ntrn], n_prev)
    #print("b")
    X_test, y_test = _load_data1(df.iloc[ntrn:], n_prev)
    return (X_train, y_train), (X_test, y_test)
# Out:
# Using TensorFlow backend.

# %%
l#864日分のtwitterデータとbitcoinの価格/ 先ずはビットコインの価格のみで予測を行う
# Out:
#           sum     price
# 0    0.344539  0.409244
# 1    0.500285  0.409235
# 2    0.400920  0.409263
# 3    0.380889  0.409385
# 4    0.420712  0.409169
# 5    0.392725  0.409650
# 6    0.339458  0.409221
# 7    0.423519  0.409130
# 8    0.290652  0.409193
# 9    0.565840  0.409351
# 10   0.522501  0.409050
# 11   0.266848  0.409172
# 12   0.429689  0.409258
# 13   0.529850  0.408931
# 14   0.321735  0.409089
# 15   0.370286  0.409280
# 16   0.661818  0.409281
# 17   0.273765  0.409095
# 18   0.380362  0.409907
# 19   0.361116  0.409465
# 20   0.400355  0.408532
# 21   0.658636  0.409239
# 22   0.012251  0.409558
# 23   1.000000  0.408991
# 24   0.000000  0.409463
# 25   0.433159  0.409324
# 26   0.509133  0.409033
# 27   0.303567  0.409328
# 28   0.333204  0.409461
# 29   0.524902  0.408949
# ..        ...       ...
# 829  0.393668  0.409586
# 830  0.386787  0.416273
# 831  0.408114  0.406724
# 832  0.433343  0.410022
# 833  0.415086  0.409446
# 834  0.398118  0.404929
# 835  0.402656  0.407625
# 836  0.481599  0.408771
# 837  0.386527  0.407492
# 838  0.400494  0.406727
# 839  0.386340  0.406902
# 840  0.452224  0.412175
# 841  0.407900  0.409149
# 842  0.387156  0.404671
# 843  0.381605  0.406853
# 844  0.416434  0.405908
# 845  0.411470  0.412096
# 846  0.384613  0.407601
# 847  0.400351  0.414559
# 848  0.463001  0.408045
# 849  0.419870  0.403744
# 850  0.358993  0.402858
# 851  0.415510  0.408204
# 852  0.470857  0.406963
# 853  0.378950  0.408330
# 854  0.388659  0.409000
# 855  0.424879  0.407066
# 856  0.422941  0.414323
# 857  0.431387  0.408026
# 858  0.366970  0.409963
#
# [859 rows x 2 columns]

# %%
#l1=l['price']

# %%
l1=ad['price']
#l1

# %%
(X_train, y_train), (X_test, y_test) = train_test_split(l1)

# %%
#X_train
a, b = X_test.shape
X_test = X_test.reshape(a, b, 1)

# %%
a, b = X_train.shape
X_train = X_train.reshape(a, b, 1)

# %%
out_neurons = 1
in_neurons=1
hidden_neurons = 300
length_of_sequences = 3

model = Sequential()
model.add(LSTM(hidden_neurons, batch_input_shape=(None, length_of_sequences, in_neurons), return_sequences=False))
model.add(Dense(out_neurons))
model.add(Activation("linear"))
model.compile(loss="mean_squared_error", optimizer="adam",)

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])
# Out:
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 12s 19ms/step - loss: 5.0307e-04 - val_loss: 0.0090
# Epoch 2/10
# 632/632 [==============================] - 0s 329us/step - loss: 4.9648e-04 - val_loss: 0.0103

# %%
pred_data = model.predict(X_test)
plt.plot(y_test, label='train')
plt.plot(pred_data, label='pred')
plt.legend(loc='upper left')
plt.show()

# %%
predp3=(pred_data>=0).reshape(len(y_test))
testp3=(y_test>=0).reshape(len(y_test))
a2=(predp3==testp3)
len(a2[a2==True])/len(a2)
# Out:
# 0.5722543352601156

# %%
ad['price'].plot()

# %%
ad['sum'].plot()

# %%
predP=pred_data>=0
testP=y_test>=0

# %%
count=0
for i in (0,len(predP)-1):
    if predP[i]==testp[i]:
        count+=1
count
# Out:
# 0

# %%
predp=predP.reshape(173)

# %%
testp=testP.reshape(173)

# %%
a=(testp==predp)

# %%
predP
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False]], dtype=bool)

# %%
len(a[a==True])/len(a)#56.06%で予測できる　次に三日前のtwitterデータを含める
# Out:
# 0.5606936416184971

# %%
ad.plot()

# %%
ad['price'].max()
# Out:
# 0.62820367955876488

# %%
ad['sum'].max()
# Out:
# 4.5455913823507608

# %%
(X_train, y_train), (X_test, y_test) = train_test_split(ad)

# %%
#a, b = X_test.shape
#X_test = X_test.reshape(a, b, 1)
#a, b = X_train.shape
#X_train = X_train.reshape(a, b, 1)

out_neurons = 1
in_neurons=2
hidden_neurons = 300
length_of_sequences = 3

model = Sequential()
model.add(LSTM(hidden_neurons, batch_input_shape=(None, length_of_sequences, in_neurons), return_sequences=False))
model.add(Dense(out_neurons))
model.add(Activation("linear"))
model.compile(loss="mean_squared_error", optimizer="adam",)

# %%
X_train.shape
# Out:
# (703, 3, 2)

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])
# Out:
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 1s 2ms/step - loss: 5.3975e-04 - val_loss: 0.0088
# Epoch 2/10
# 632/632 [==============================] - 0s 231us/step - loss: 5.1990e-04 - val_loss: 0.0095

# %%
pred_data = model.predict(X_test)
plt.plot(y_test, label='train')
plt.plot(pred_data, label='pred')
plt.legend(loc='upper left')
plt.show()

# %%
predp2=(pred_data>=0).reshape(173)

# %%
testp2=(y_test>=0).reshape(173)

# %%
a2=(predp2==testp2)

# %%
len(a2[a2==True])/len(a2)#ラグを取らないでそのままtwitterデータを組み込んで予測した場合は５３.８％の予測精度
# Out:
# 0.5375722543352601

# %%
newa=ad

# %%
newa['sum']=newa['sum'].shift(3)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
newa=newa.dropna()

# %%
newa=newa.reset_index()

# %%
newa=newa.drop("index",axis=1)

# %%
newa
# Out:
#           sum     price
# 0    0.098503  0.006180
# 1    0.192061 -0.000895
# 2   -0.121357 -0.002400
# 3    0.229619 -0.001359
# 4   -0.395527  0.001254
# 5    0.428552 -0.003711
# 6   -0.263287 -0.001701
# 7   -0.024899 -0.000281
# 8    0.279175 -0.005678
# 9   -0.086207 -0.003079
# 10  -0.069422  0.000084
# 11  -0.026793  0.000091
# 12  -0.008981 -0.002978
# 13   0.545751  0.010416
# 14  -0.676353  0.003124
# 15   0.525242 -0.012252
# 16  -0.112992 -0.000595
# 17  -0.462646  0.004660
# 18   0.347057 -0.004684
# 19  -0.192709  0.003101
# 20  -0.059397  0.000798
# 21   0.480815 -0.003989
# 22  -0.467023  0.000863
# 23   1.926157  0.003052
# 24  -1.673719 -0.005382
# 25  -0.230670  0.002619
# 26   0.593545 -0.004424
# 27  -0.553278 -0.001032
# 28  -0.037910  0.008766
# 29   0.522411 -0.004272
# ..        ...       ...
# 847  1.983953  0.115330
# 848 -0.013582 -0.042055
# 849 -0.014541  0.012309
# 850 -3.004148  0.002818
# 851 -1.075346 -0.071639
# 852 -0.010786 -0.027198
# 853  0.036557 -0.008305
# 854 -0.019036 -0.029393
# 855  0.015252 -0.042004
# 856 -0.082881 -0.039112
# 857  0.059827  0.047793
# 858  0.076391 -0.002087
# 859  0.012835 -0.075882
# 860 -0.077115 -0.039919
# 861  0.055640 -0.055497
# 862  0.177436  0.046483
# 863 -0.079845 -0.027590
# 864 -0.109185  0.087094
# 865 -0.097537 -0.020275
# 866  0.041805 -0.091171
# 867 -0.049114 -0.105771
# 868 -0.004012 -0.017653
# 869  0.012969 -0.038110
# 870  0.027371 -0.015574
# 871  0.083522 -0.004534
# 872 -0.146035 -0.036411
# 873  0.043362  0.083202
# 874  0.105571 -0.020585
# 875  0.082918  0.011328
# 876 -0.061003  0.020363
#
# [877 rows x 2 columns]

# %%
(X_train, y_train), (X_test, y_test) = train_test_split(newa)

# %%
history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])
# Out:
# Train on 629 samples, validate on 70 samples
# Epoch 1/10
# 629/629 [==============================] - 0s 300us/step - loss: 5.3253e-04 - val_loss: 0.0132
# Epoch 2/10
# 629/629 [==============================] - 0s 322us/step - loss: 4.9920e-04 - val_loss: 0.0131
# Epoch 3/10
# 629/629 [==============================] - 0s 223us/step - loss: 5.1933e-04 - val_loss: 0.0131
# Epoch 4/10
# 629/629 [==============================] - 0s 283us/step - loss: 5.1471e-04 - val_loss: 0.0131
# Epoch 5/10
# 629/629 [==============================] - 0s 300us/step - loss: 5.0876e-04 - val_loss: 0.0132

# %%
pred_data = model.predict(X_test)
plt.plot(y_test, label='train')
plt.plot(pred_data, label='pred')
plt.legend(loc='upper left')
plt.show()

# %%
predp3=(pred_data>=0).reshape(172)
testp3=(y_test>=0).reshape(172)
a2=(predp3==testp3)

# %%
len(a2[a2==True])/len(a2)#二日のラグをとった場合
# Out:
# 0.45930232558139533

# %%
data = pd.read_csv('bit-kyokusei-re.csv')

# %%
#a

# %%
b.plot()

# %%
np.log(-2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
# nan

# %%
bitm=b-b.shift(1)

# %%
bitm=bitm.dropna()
bitm=bitm.reset_index()

# %%
bitm=bitm.drop("index",axis=1)

# %%
bitm.plot()

# %%
bitz=pd.DataFrame(data=zscore.zscore(bitm),  columns=['sum','price'], dtype='float')

# %%
bitm["sum"].mean()
# Out:
# 0.00029337769971211469

# %%
bitm.plot()

# %%
b.plot()

# %%
(X_train, y_train), (X_test, y_test) = train_test_split(bitm)
out_neurons = 1
in_neurons=2
hidden_neurons = 300
length_of_sequences = 3

model = Sequential()
model.add(LSTM(hidden_neurons, batch_input_shape=(None, length_of_sequences, in_neurons), return_sequences=False))
model.add(Dense(out_neurons))
model.add(Activation("linear"))
model.compile(loss="mean_squared_error", optimizer="adam",)
early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])
pred_data = model.predict(X_test)
plt.plot(y_test, label='train')
plt.plot(pred_data, label='pred')
plt.legend(loc='upper left')
plt.show()
# Out:
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 1s 2ms/step - loss: 5.1297e-04 - val_loss: 0.0085
# Epoch 2/10
# 632/632 [==============================] - 0s 233us/step - loss: 5.4144e-04 - val_loss: 0.0090

# %%
predp3=(pred_data>=0).reshape(len(y_test))
testp3=(y_test>=0).reshape(len(y_test))
a2=(predp3==testp3)
len(a2[a2==True])/len(a2)
# Out:
# 0.5144508670520231

# %%
bitm3=(bitm-bitm.shift(2)).dropna()

# %%
bitm3=bitm3.reset_index()

# %%
(X_train, y_train), (X_test, y_test) = train_test_split(bitm3)
out_neurons = 1
in_neurons=2
hidden_neurons = 300
length_of_sequences = 3

model = Sequential()
model.add(LSTM(hidden_neurons, batch_input_shape=(None, length_of_sequences, in_neurons), return_sequences=False))
model.add(Dense(out_neurons))
model.add(Activation("linear"))
model.compile(loss="mean_squared_error", optimizer="adam",)
early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])
pred_data = model.predict(X_test)
plt.plot(y_test, label='train')
plt.plot(pred_data, label='pred')
plt.legend(loc='upper left')
plt.show()
predp3=(pred_data>=0).reshape(len(y_test))
testp3=(y_test>=0).reshape(len(y_test))
a2=(predp3==testp3)
len(a2[a2==True])/len(a2)
# Out:
# Train on 630 samples, validate on 71 samples
# Epoch 1/10
# 630/630 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0116
# Epoch 2/10
# 630/630 [==============================] - 0s 229us/step - loss: 0.0011 - val_loss: 0.0121
# 0.5491329479768786

# %%
bitm3=bitm3.drop("index",axis=1)

# %%
bitm3
# Out:
#           sum     price
# 0   -0.219860  0.000314
# 1    0.037559  0.002469
# 2   -0.274170 -0.001541
# 3    0.198933  0.004371
# 4    0.132240  0.000851
# 5   -0.453451 -0.008580
# 6    0.542461 -0.000464
# 7   -0.061309  0.003654
# 8   -0.348597 -0.002351
# 9    0.059415 -0.002955
# 10   0.060440  0.003430
# 11   0.572544 -0.003976
# 12  -0.667371 -0.002799
# 13  -0.020509  0.005762
# 14   0.563361  0.003170
# 15  -0.987888 -0.003063
# 16   0.460049  0.010325
# 17   0.269938  0.006102
# 18  -0.406453 -0.022668
# 19   0.673524 -0.003719
# 20  -0.407627  0.016913
# 21   1.445342 -0.004088
# 22  -1.206696 -0.001560
# 23  -2.156827  0.005481
# 24   2.267263 -0.007090
# 25  -0.322608  0.000065
# 26  -0.631455  0.007041
# 27   1.075689 -0.006245
# 28  -0.732902 -0.000433
# 29  -0.475453  0.000958
# ..        ...       ...
# 850  2.993361  0.119574
# 851  1.111903 -0.047173
# 852 -0.008250 -0.103021
# 853 -0.021306  0.044872
# 854 -0.063844 -0.083949
# 855  0.044576 -0.030015
# 856  0.159272  0.063334
# 857 -0.046992 -0.002195
# 858 -0.153507 -0.033699
# 859  0.042805 -0.009720
# 860  0.254551  0.089797
# 861 -0.135485  0.037025
# 862 -0.286621 -0.123675
# 863 -0.017692 -0.037831
# 864  0.150990  0.020385
# 865  0.048423  0.086401
# 866 -0.045817  0.027907
# 867  0.062083  0.040611
# 868  0.031382  0.007315
# 869  0.070553 -0.178265
# 870 -0.173406 -0.085496
# 871 -0.040161  0.073518
# 872  0.251606  0.067661
# 873  0.039557  0.002079
# 874 -0.166574  0.033576
# 875 -0.088237 -0.020836
# 876  0.131086  0.087735
# 877  0.053854  0.015826
# 878 -0.072826 -0.071874
# 879 -0.222928  0.040949
#
# [880 rows x 2 columns]

# %%
#bitm

# %%
(X_train, y_train), (X_test, y_test) = train_test_split(bitm["price"])

a, b = X_test.shape
X_test = X_test.reshape(a, b, 1)

a, b = X_train.shape
X_train = X_train.reshape(a, b, 1)

out_neurons = 1
in_neurons=1
hidden_neurons = 300
length_of_sequences = 3

model = Sequential()
model.add(LSTM(hidden_neurons, batch_input_shape=(None, length_of_sequences, in_neurons), return_sequences=False))
model.add(Dense(out_neurons))
model.add(Activation("linear"))
model.compile(loss="mean_squared_error", optimizer="adam",)
early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])
pred_data = model.predict(X_test)
plt.plot(y_test, label='train')
plt.plot(pred_data, label='pred')
plt.legend(loc='upper left')
plt.show()
predp3=(pred_data>=0).reshape(len(y_test))
testp3=(y_test>=0).reshape(len(y_test))
a2=(predp3==testp3)
len(a2[a2==True])/len(a2)
# Out:
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 1s 2ms/step - loss: 5.0628e-04 - val_loss: 0.0089
# Epoch 2/10
# 632/632 [==============================] - 0s 230us/step - loss: 5.0291e-04 - val_loss: 0.0095
# 0.5606936416184971

# %%
bitm3=(bitm-bitm.shift(3)).dropna()
bitm3=bitm3.reset_index()
bitm3=bitm3.drop("index",axis=1)

(X_train, y_train), (X_test, y_test) = train_test_split(bitm3)

out_neurons = 1
in_neurons=2
hidden_neurons = 300
length_of_sequences = 3

model = Sequential()
model.add(LSTM(hidden_neurons, batch_input_shape=(None, length_of_sequences, in_neurons), return_sequences=False))
model.add(Dense(out_neurons))
model.add(Activation("linear"))
model.compile(loss="mean_squared_error", optimizer="adam",)
early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])
pred_data = model.predict(X_test)
plt.plot(y_test, label='train')
plt.plot(pred_data, label='pred')
plt.legend(loc='upper left')
plt.show()
predp3=(pred_data>=0).reshape(len(y_test))
testp3=(y_test>=0).reshape(len(y_test))
a2=(predp3==testp3)
len(a2[a2==True])/len(a2)
# Out:
# Train on 630 samples, validate on 70 samples
# Epoch 1/10
# 630/630 [==============================] - 2s 3ms/step - loss: 0.0013 - val_loss: 0.0100
# Epoch 2/10
# 630/630 [==============================] - 0s 227us/step - loss: 0.0011 - val_loss: 0.0099
# Epoch 3/10
# 630/630 [==============================] - 0s 252us/step - loss: 0.0012 - val_loss: 0.0096
# Epoch 4/10
# 630/630 [==============================] - 0s 332us/step - loss: 0.0011 - val_loss: 0.0096
# Epoch 5/10
# 630/630 [==============================] - 0s 268us/step - loss: 0.0011 - val_loss: 0.0097
# 0.5606936416184971

# %%
bitm3=(bitm-bitm.shift(4)).dropna()
bitm3=bitm3.reset_index()
bitm3=bitm3.drop("index",axis=1)

(X_train, y_train), (X_test, y_test) = train_test_split(bitm3)

out_neurons = 1
in_neurons=2
hidden_neurons = 300
length_of_sequences = 3

model = Sequential()
model.add(LSTM(hidden_neurons, batch_input_shape=(None, length_of_sequences, in_neurons), return_sequences=False))
model.add(Dense(out_neurons))
model.add(Activation("linear"))
model.compile(loss="mean_squared_error", optimizer="adam",)
early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])
pred_data = model.predict(X_test)
plt.plot(y_test, label='train')
plt.plot(pred_data, label='pred')
plt.legend(loc='upper left')
plt.show()
predp3=(pred_data>=0).reshape(len(y_test))
testp3=(y_test>=0).reshape(len(y_test))
a2=(predp3==testp3)
len(a2[a2==True])/len(a2)
# Out:
# Train on 629 samples, validate on 70 samples
# Epoch 1/10
# 629/629 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0133
# Epoch 2/10
# 629/629 [==============================] - 0s 245us/step - loss: 0.0010 - val_loss: 0.0137
# 0.5202312138728323

# %%
bitm3=(bitm-bitm.shift(9)).dropna()
bitm3=bitm3.reset_index()
bitm3=bitm3.drop("index",axis=1)

(X_train, y_train), (X_test, y_test) = train_test_split(bitm3)

out_neurons = 1
in_neurons=2
hidden_neurons = 300
length_of_sequences = 3

model = Sequential()
model.add(LSTM(hidden_neurons, batch_input_shape=(None, length_of_sequences, in_neurons), return_sequences=False))
model.add(Dense(out_neurons))
model.add(Activation("linear"))
model.compile(loss="mean_squared_error", optimizer="adam",)
early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])
pred_data = model.predict(X_test)
plt.plot(y_test, label='train')
plt.plot(pred_data, label='pred')
plt.legend(loc='upper left')
plt.show()
predp3=(pred_data>=0).reshape(len(y_test))
testp3=(y_test>=0).reshape(len(y_test))
a2=(predp3==testp3)
len(a2[a2==True])/len(a2)
# Out:
# Train on 625 samples, validate on 70 samples
# Epoch 1/10
# 625/625 [==============================] - 2s 2ms/step - loss: 0.0011 - val_loss: 0.0152
# Epoch 2/10
# 625/625 [==============================] - 0s 232us/step - loss: 0.0011 - val_loss: 0.0154
# 0.4941860465116279

# %%
bitm=ad.copy()
bitm3=(bitm-bitm.shift(2)).dropna()
bitm3=bitm3.reset_index()
bitm3=bitm3.drop("index",axis=1)

(X_train, y_train), (X_test, y_test) = train_test_split(bitm3)

out_neurons = 1
in_neurons=2
hidden_neurons = 300
length_of_sequences = 3

model = Sequential()
model.add(LSTM(hidden_neurons, batch_input_shape=(None, length_of_sequences, in_neurons), return_sequences=False))
model.add(Dense(out_neurons))
model.add(Activation("linear"))
model.compile(loss="mean_squared_error", optimizer="adam",)
early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])
pred_data = model.predict(X_test)
plt.plot(y_test, label='train')
plt.plot(pred_data, label='pred')
plt.legend(loc='upper left')
plt.show()
predp3=(pred_data>=0).reshape(len(y_test))
testp3=(y_test>=0).reshape(len(y_test))
a2=(predp3==testp3)
len(a2[a2==True])/len(a2)
# Out:
# Train on 630 samples, validate on 71 samples
# Epoch 1/10
# 630/630 [==============================] - 15s 23ms/step - loss: 9.6848e-04 - val_loss: 0.0121
# Epoch 2/10
# 630/630 [==============================] - 0s 284us/step - loss: 0.0011 - val_loss: 0.0122
# 0.5375722543352601

# %%
per=[]
from keras.models import Sequential  
from keras.layers.core import Dense, Activation  
from keras.layers.recurrent import LSTM
from keras.callbacks import EarlyStopping
def _load_data1(data, n_prev=3):
    docX, docY = [], []
    for i in range(len(data)-n_prev):
        #print(i)
        docX.append(data.iloc[i:i+n_prev].as_matrix())
        docY.append(data['price'].iloc[i+n_prev])#data['price']
    alsX = np.array(docX)
    alsY = np.array(docY)
    return alsX, alsY

def _load_data(data, n_prev=3):
    docX, docY = [], []
    for i in range(len(data)-n_prev):
        #print(i)
        docX.append(data.iloc[i:i+n_prev].as_matrix())
        docY.append(data.iloc[i+n_prev])#data['price']
    alsX = np.array(docX)
    alsY = np.array(docY)
    return alsX, alsY

def train_test_split(df, test_size=0.2, n_prev=3):
    ntrn = round(len(df) * (1 - test_size))
    ntrn = int(ntrn)
    #print("a")
    X_train, y_train = _load_data1(df.iloc[0:ntrn], n_prev)
    #print("b")
    X_test, y_test = _load_data1(df.iloc[ntrn:], n_prev)
    return (X_train, y_train), (X_test, y_test)


early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
pe=0
for j in range(0,10):
    sss=0
    pe=0
    bitmcp=ad.copy()#bitm.copy()
    bitmcp["sum"]=bitmcp["sum"].shift(j)
    bitmcp=bitmcp.dropna().reset_index(drop=True)
    for i in range(6):
        
        #bitm3=(bitm-bitm.shift(j)).dropna()
        #bitm3=bitm3.reset_index()
        #bitm3=bitm3.drop("index",axis=1)

        (X_train, y_train), (X_test, y_test) = train_test_split(bitmcp)

        out_neurons = 1
        in_neurons=2
        hidden_neurons = 300
        length_of_sequences = 3

        model = Sequential()
        model.add(LSTM(hidden_neurons, batch_input_shape=(None, length_of_sequences, in_neurons), return_sequences=False))
        model.add(Dense(out_neurons))
        model.add(Activation("linear"))
        model.compile(loss="mean_squared_error", optimizer="adam",)
        early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
        history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])
        pred_data = model.predict(X_test)
        plt.plot(y_test, label='train')
        plt.plot(pred_data, label='pred')
        plt.legend(loc='upper left')
        #plt.show()
        predp3=(pred_data>=0).reshape(len(y_test))
        testp3=(y_test>=0).reshape(len(y_test))
        a2=(predp3==testp3)
        if pe<len(a2[a2==True])/len(a2):
            pe=len(a2[a2==True])/len(a2)
    per.append([str(j),pe])
# Out:
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 1s 2ms/step - loss: 8.5335e-04 - val_loss: 0.0088
# Epoch 2/10
# 632/632 [==============================] - 0s 250us/step - loss: 5.6043e-04 - val_loss: 0.0097
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 1s 2ms/step - loss: 5.1993e-04 - val_loss: 0.0089
# Epoch 2/10
# 632/632 [==============================] - 0s 247us/step - loss: 5.0930e-04 - val_loss: 0.0095
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 1s 2ms/step - loss: 5.8742e-04 - val_loss: 0.0088
# Epoch 2/10
# 632/632 [==============================] - 0s 277us/step - loss: 5.3187e-04 - val_loss: 0.0096
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 1s 2ms/step - loss: 5.4928e-04 - val_loss: 0.0087
# Epoch 2/10
# 632/632 [==============================] - 0s 256us/step - loss: 5.7419e-04 - val_loss: 0.0095
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0088
# Epoch 2/10
# 632/632 [==============================] - 0s 295us/step - loss: 7.0055e-04 - val_loss: 0.0096
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 1s 2ms/step - loss: 5.4231e-04 - val_loss: 0.0089
# 625/625 [==============================] - 0s 272us/step - loss: 5.8706e-04 - val_loss: 0.0128
# Epoch 4/10
# 625/625 [==============================] - 0s 297us/step - loss: 5.3513e-04 - val_loss: 0.0131
# Train on 625 samples, validate on 70 samples
# Epoch 1/10
# 625/625 [==============================] - 6s 10ms/step - loss: 5.4328e-04 - val_loss: 0.0125
# Epoch 2/10
# 625/625 [==============================] - 0s 231us/step - loss: 5.2865e-04 - val_loss: 0.0129
# Train on 625 samples, validate on 70 samples
# Epoch 1/10
# 625/625 [==============================] - 6s 10ms/step - loss: 5.4600e-04 - val_loss: 0.0127
# Epoch 2/10
# 625/625 [==============================] - 0s 229us/step - loss: 5.2053e-04 - val_loss: 0.0129

# %%
per
# Out:
# [['0', 0.5780346820809249],
#  ['1', 0.5549132947976878],
#  ['2', 0.5549132947976878],
#  ['3', 0.5722543352601156],
#  ['4', 0.5549132947976878],
#  ['5', 0.5697674418604651],
#  ['6', 0.5755813953488372],
#  ['7', 0.5755813953488372],
#  ['8', 0.5581395348837209],
#  ['9', 0.622093023255814]]

# %%
per
# Out:
# [['0', 0.5549132947976878],
#  ['1', 0.5491329479768786],
#  ['2', 0.5606936416184971],
#  ['3', 0.5780346820809249],
#  ['4', 0.5722543352601156],
#  ['5', 0.563953488372093],
#  ['6', 0.5755813953488372],
#  ['7', 0.5697674418604651],
#  ['8', 0.563953488372093],
#  ['9', 0.563953488372093]]

# %%
p
# Out:
# 0.5352601156069364

# %%
# Out:
# 0.5127167630057804

# %%
#_loaddata1は二変数用　_loaddataは一変数用

def _load_data1(data, n_prev=3):
    docX, docY = [], []
    for i in range(len(data)-n_prev):
        #print(i)
        docX.append(data.iloc[i:i+n_prev].as_matrix())
        docY.append(data['price'].iloc[i+n_prev])#data['price']
    alsX = np.array(docX)
    alsY = np.array(docY)
    return alsX, alsY

def _load_data(data, n_prev=3):
    docX, docY = [], []
    for i in range(len(data)-n_prev):
        #print(i)
        docX.append(data.iloc[i:i+n_prev].as_matrix())
        docY.append(data.iloc[i+n_prev])#data['price']
    alsX = np.array(docX)
    alsY = np.array(docY)
    return alsX, alsY

def train_test_split(df, test_size=0.2, n_prev=3):
    ntrn = round(len(df) * (1 - test_size))
    ntrn = int(ntrn)
    #print("a")
    X_train, y_train = _load_data1(df.iloc[0:ntrn], n_prev)
    #print("b")
    X_test, y_test = _load_data1(df.iloc[ntrn:], n_prev)
    return (X_train, y_train), (X_test, y_test)

# %%
ad['price'].plot()

# %%
def _load_data(data, n_prev=3):
    docX, docY = [], []
    for i in range(len(data)-n_prev):
        #print(i)
        docX.append(data.iloc[i:i+n_prev].as_matrix())
        docY.append(data.iloc[i+n_prev])#data['price']
    alsX = np.array(docX)
    alsY = np.array(docY)
    return alsX, alsY

def train_test_split(df, test_size=0.2, n_prev=3):
    ntrn = round(len(df) * (1 - test_size))
    ntrn = int(ntrn)
    #print("a")
    X_train, y_train = _load_data(df.iloc[0:ntrn], n_prev)
    #print("b")
    X_test, y_test = _load_data(df.iloc[ntrn:], n_prev)
    return (X_train, y_train), (X_test, y_test)

bitm3=ad['price'].copy()#bitm["price"].copy()#(bitm["price"]-bitm["price"].shift(1)).dropna()
#bitm3=bitm3.reset_index()
#bitm3=bitm3.drop("index",axis=1)
sss=0
(X_train, y_train), (X_test, y_test) = train_test_split(bitm3)
m, n=X_train.shape
X_train=X_train.reshape(m,n,1)
m, n=X_test.shape
X_test=X_test.reshape(m,n,1)
out_neurons = 1
in_neurons=1
hidden_neurons = 300
length_of_sequences = 3

model = Sequential()
model.add(LSTM(hidden_neurons, batch_input_shape=(None, length_of_sequences, in_neurons), return_sequences=False))
model.add(Dense(out_neurons))
model.add(Activation("linear"))
model.compile(loss="mean_squared_error", optimizer="adam",)
early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
pe=0
for i in range(10):
    history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])
    pred_data = model.predict(X_test)
    #plt.plot(y_test, label='train')
    #plt.plot(pred_data, label='pred')
    #plt.legend(loc='upper left')
    #plt.show()
    predp3=(pred_data>=0).reshape(len(y_test))
    testp3=(y_test>=0).reshape(len(y_test))
    a2=(predp3==testp3)
    #sss+=len(a2[a2==True])/len(a2)
    if pe<len(a2[a2==True])/len(a2):
        pe=len(a2[a2==True])/len(a2)
pe
# Out:
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 43s 69ms/step - loss: 5.1600e-04 - val_loss: 0.0088
# Epoch 2/10
# 632/632 [==============================] - 0s 268us/step - loss: 5.0774e-04 - val_loss: 0.0099
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 0s 219us/step - loss: 6.5272e-04 - val_loss: 0.0100
# Epoch 2/10
# 632/632 [==============================] - 0s 308us/step - loss: 6.4699e-04 - val_loss: 0.0092
# Epoch 3/10
# 632/632 [==============================] - 0s 309us/step - loss: 5.1044e-04 - val_loss: 0.0087
# Epoch 4/10
# 632/632 [==============================] - 0s 338us/step - loss: 5.4651e-04 - val_loss: 0.0086
# Epoch 5/10
# 632/632 [==============================] - 0s 264us/step - loss: 5.7626e-04 - val_loss: 0.0088
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 0s 230us/step - loss: 5.2454e-04 - val_loss: 0.0091
# Epoch 2/10
# 632/632 [==============================] - 0s 289us/step - loss: 5.0057e-04 - val_loss: 0.0093
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 0s 243us/step - loss: 5.1866e-04 - val_loss: 0.0094
# Epoch 2/10
# 632/632 [==============================] - 0s 331us/step - loss: 5.2806e-04 - val_loss: 0.0093
# Epoch 3/10
# 632/632 [==============================] - 0s 258us/step - loss: 5.0992e-04 - val_loss: 0.0091
# Epoch 4/10
# 632/632 [==============================] - 0s 300us/step - loss: 4.9881e-04 - val_loss: 0.0089
# Epoch 5/10
# 632/632 [==============================] - 0s 284us/step - loss: 5.0153e-04 - val_loss: 0.0088
# Epoch 6/10
# 632/632 [==============================] - 0s 303us/step - loss: 5.1131e-04 - val_loss: 0.0088
# Epoch 7/10
# 632/632 [==============================] - 0s 286us/step - loss: 5.1825e-04 - val_loss: 0.0088
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 0s 260us/step - loss: 5.1184e-04 - val_loss: 0.0090
# Epoch 2/10
# 632/632 [==============================] - 0s 308us/step - loss: 4.9871e-04 - val_loss: 0.0092
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 0s 250us/step - loss: 4.9746e-04 - val_loss: 0.0094
# Epoch 2/10
# 632/632 [==============================] - 0s 299us/step - loss: 5.1081e-04 - val_loss: 0.0095
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 0s 244us/step - loss: 5.2386e-04 - val_loss: 0.0094
# Epoch 2/10
# 632/632 [==============================] - 0s 294us/step - loss: 5.1854e-04 - val_loss: 0.0093
# Epoch 3/10
# 632/632 [==============================] - 0s 281us/step - loss: 5.0370e-04 - val_loss: 0.0092
# Epoch 4/10
# 632/632 [==============================] - 0s 292us/step - loss: 4.9482e-04 - val_loss: 0.0090
# Epoch 5/10
# 632/632 [==============================] - 0s 301us/step - loss: 4.9444e-04 - val_loss: 0.0090
# Epoch 6/10
# 632/632 [==============================] - 0s 283us/step - loss: 4.9974e-04 - val_loss: 0.0090
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 0s 250us/step - loss: 5.0033e-04 - val_loss: 0.0091
# Epoch 2/10
# 632/632 [==============================] - 0s 311us/step - loss: 4.9364e-04 - val_loss: 0.0092
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 0s 241us/step - loss: 4.8793e-04 - val_loss: 0.0095
# Epoch 2/10
# 632/632 [==============================] - 0s 312us/step - loss: 4.9811e-04 - val_loss: 0.0096
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 0s 243us/step - loss: 5.0745e-04 - val_loss: 0.0095
# Epoch 2/10
# 632/632 [==============================] - 0s 297us/step - loss: 4.9843e-04 - val_loss: 0.0094
# Epoch 3/10
# 632/632 [==============================] - 0s 287us/step - loss: 4.8787e-04 - val_loss: 0.0092
# Epoch 4/10
# 632/632 [==============================] - 0s 292us/step - loss: 4.8665e-04 - val_loss: 0.0092
# Epoch 5/10
# 632/632 [==============================] - 0s 297us/step - loss: 4.8953e-04 - val_loss: 0.0092
# Epoch 6/10
# 632/632 [==============================] - 0s 289us/step - loss: 4.9006e-04 - val_loss: 0.0092
# 0.5664739884393064

# %%
sss
# Out:
# 4.7514450867052025

# %%
bitm3=ad['price'].copy()#bitm["price"].copy()#(bitm["price"]-bitm["price"].shift(1)).dropna()
#bitm3=bitm3.reset_index()
#bitm3=bitm3.drop("index",axis=1)
sss=0
(X_train, y_train), (X_test, y_test) = train_test_split(bitm3)
m, n=X_train.shape
X_train=X_train.reshape(m,n,1)
m, n=X_test.shape
X_test=X_test.reshape(m,n,1)
out_neurons = 1
in_neurons=1
hidden_neurons = 300
length_of_sequences = 3
for i in range(10):
    model = Sequential()
    model.add(LSTM(hidden_neurons, batch_input_shape=(None, length_of_sequences, in_neurons), return_sequences=False))
    model.add(Dense(out_neurons))
    model.add(Activation("linear"))
    model.compile(loss="mean_squared_error", optimizer="adam",)
    early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
#for i in range(2):
    history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])
    pred_data = model.predict(X_test)
        #plt.plot(y_test, label='train')
        #plt.plot(pred_data, label='pred')
        #plt.legend(loc='upper left')
        #plt.show()
    predp3=(pred_data>=0).reshape(len(y_test))
    testp3=(y_test>=0).reshape(len(y_test))
    a2=(predp3==testp3)
    print(len(a2[a2==True])/len(a2))
    sss+=len(a2[a2==True])/len(a2)
sss
# Out:
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 12s 19ms/step - loss: 5.0209e-04 - val_loss: 0.0089
# Epoch 2/10
# 632/632 [==============================] - 0s 276us/step - loss: 5.1292e-04 - val_loss: 0.0094
# 0.5664739884393064
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 11s 18ms/step - loss: 5.1395e-04 - val_loss: 0.0090
# Epoch 2/10
# 632/632 [==============================] - 0s 299us/step - loss: 4.9931e-04 - val_loss: 0.0100
# 0.5664739884393064
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 12s 19ms/step - loss: 4.9759e-04 - val_loss: 0.0088
# Epoch 2/10
# 632/632 [==============================] - 0s 273us/step - loss: 5.1870e-04 - val_loss: 0.0097
# 0.5375722543352601
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 12s 18ms/step - loss: 5.0749e-04 - val_loss: 0.0091
# Epoch 2/10
# 632/632 [==============================] - 0s 294us/step - loss: 4.9909e-04 - val_loss: 0.0098
# 0.5491329479768786
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 12s 19ms/step - loss: 5.0891e-04 - val_loss: 0.0089
# Epoch 2/10
# 632/632 [==============================] - 0s 278us/step - loss: 5.1038e-04 - val_loss: 0.0095
# 0.5491329479768786
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 17s 28ms/step - loss: 5.0300e-04 - val_loss: 0.0090
# Epoch 2/10
# 632/632 [==============================] - 0s 445us/step - loss: 5.0766e-04 - val_loss: 0.0096
# 0.5606936416184971
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 13s 21ms/step - loss: 4.9931e-04 - val_loss: 0.0089
# Epoch 2/10
# 632/632 [==============================] - 0s 500us/step - loss: 5.0681e-04 - val_loss: 0.0096
# 0.5433526011560693
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 15s 24ms/step - loss: 5.1602e-04 - val_loss: 0.0087
# Epoch 2/10
# 632/632 [==============================] - 0s 348us/step - loss: 5.1870e-04 - val_loss: 0.0096
# 0.5491329479768786
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 13s 20ms/step - loss: 5.1036e-04 - val_loss: 0.0091
# Epoch 2/10
# 632/632 [==============================] - 0s 275us/step - loss: 5.0323e-04 - val_loss: 0.0096
# 0.5722543352601156
# Train on 632 samples, validate on 71 samples
# Epoch 1/10
# 632/632 [==============================] - 12s 20ms/step - loss: 5.0751e-04 - val_loss: 0.0088
# Epoch 2/10
# 632/632 [==============================] - 0s 322us/step - loss: 5.0719e-04 - val_loss: 0.0095
# 0.5491329479768786
# 5.543352601156069

# %%
#bitm=bitm.dropna().reset_index(drop=True)
#bitm
#for i in range(10):
#    print(i)

# %%
#bitm['price']

# %%
#bitm3

# %%
#bitm

# %%
bitmcp=bitm.copy()

# %%
bitmcp["sum"]=bitmcp["sum"].shift(2)
bitmcp
# Out:
#      index       sum     price
# 0        1       NaN -0.000519
# 1        2       NaN -0.000661
# 2        3  0.098503 -0.000205
# 3        4  0.192061  0.001809
# 4        5 -0.121357 -0.001746
# 5        6  0.229619  0.006180
# 6        7 -0.395527 -0.000895
# 7        8  0.428552 -0.002400
# 8        9 -0.263287 -0.001359
# 9       10 -0.024899  0.001254
# 10      11  0.279175 -0.003711
# 11      12 -0.086207 -0.001701
# 12      13 -0.069422 -0.000281
# 13      14 -0.026793 -0.005678
# 14      15 -0.008981 -0.003079
# 15      16  0.545751  0.000084
# 16      17 -0.676353  0.000091
# 17      18  0.525242 -0.002978
# 18      19 -0.112992  0.010416
# 19      20 -0.462646  0.003124
# 20      21  0.347057 -0.012252
# 21      22 -0.192709 -0.000595
# 22      23 -0.059397  0.004660
# 23      24  0.480815 -0.004684
# 24      25 -0.467023  0.003101
# 25      26  1.926157  0.000798
# 26      27 -1.673719 -0.003989
# 27      28 -0.230670  0.000863
# 28      29  0.593545  0.003052
# 29      30 -0.553278 -0.005382
# ..     ...       ...       ...
# 852    853 -3.004148  0.115330
# 853    854 -1.075346 -0.042055
# 854    855 -0.010786  0.012309
# 855    856  0.036557  0.002818
# 856    857 -0.019036 -0.071639
# 857    858  0.015252 -0.027198
# 858    859 -0.082881 -0.008305
# 859    860  0.059827 -0.029393
# 860    861  0.076391 -0.042004
# 861    862  0.012835 -0.039112
# 862    863 -0.077115  0.047793
# 863    864  0.055640 -0.002087
# 864    865  0.177436 -0.075882
# 865    866 -0.079845 -0.039919
# 866    867 -0.109185 -0.055497
# 867    868 -0.097537  0.046483
# 868    869  0.041805 -0.027590
# 869    870 -0.049114  0.087094
# 870    871 -0.004012 -0.020275
# 871    872  0.012969 -0.091171
# 872    873  0.027371 -0.105771
# 873    874  0.083522 -0.017653
# 874    875 -0.146035 -0.038110
# 875    876  0.043362 -0.015574
# 876    877  0.105571 -0.004534
# 877    878  0.082918 -0.036411
# 878    879 -0.061003  0.083202
# 879    880 -0.005319 -0.020585
# 880    881  0.070084  0.011328
# 881    882  0.048535  0.020363
#
# [882 rows x 3 columns]

# %%
bitm=bitm.drop("index",axis=1)
bitmcp=bitmcp.drop("index",axis=1)

# %%
data = pd.read_csv('bit-kyokusei-re.csv')

# %%
#data=data.drop("Unnamed")

# %%
a.to_csv("newBitdata")

# %%
b=zscore.zscore(a)

# %%
bitm=b-b.shift(1)

# %%
bitm=bitm.dropna()
bitm=bitm.reset_index()

# %%
#bitmcp.dropna().reset_index(drop=True)

# %%
data1=data1.drop("Date",axis=1)

# %%
data1['Price']=data1['Price'].str.replace(',','')
data1['Price']=data1['Price'].astype(float)
data1=data1.interpolate()

# %%
data1.plot()

# %%
#import scipy.stats as zscore
#data2=zscore.zscore(data1,axis=0)
#data2.plot()

# %%
data2=np.log(data1)-np.log(data1.shift(1))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
data2=data2.dropna()

# %%
data2.plot()

# %%
#LSTMによる予測

from keras.models import Sequential  
from keras.layers.core import Dense, Activation  
from keras.layers.recurrent import LSTM
#_loaddata1は二変数用　_loaddataは一変数用
n=3

def _load_data1(data, n_prev=n):
    docX, docY = [], []
    for i in range(len(data)-n_prev):
        #print(i)
        docX.append(data.iloc[i:i+n_prev].as_matrix())
        docY.append(data['price'].iloc[i+n_prev])#data['price']
    alsX = np.array(docX)
    alsY = np.array(docY)
    return alsX, alsY

def _load_data(data, n_prev=n):
    docX, docY = [], []
    for i in range(len(data)-n_prev):
        #print(i)
        docX.append(data.iloc[i:i+n_prev].as_matrix())
        docY.append(data.iloc[i+n_prev])#data['price']
    alsX = np.array(docX)
    alsY = np.array(docY)
    return alsX, alsY

def train_test_split(df, test_size=0.2, n_prev=n):
    ntrn = round(len(df) * (1 - test_size))
    ntrn = int(ntrn)
    #print("a")
    X_train, y_train = _load_data1(df.iloc[0:ntrn], n_prev)
    #print("b")
    X_test, y_test = _load_data1(df.iloc[ntrn:], n_prev)
    return (X_train, y_train), (X_test, y_test)
# Out:
# Using TensorFlow backend.

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])

(X_train, y_train), (X_test, y_test) = train_test_split(data2["Price"])

a, b = X_test.shape
X_test = X_test.reshape(a, b, 1)

a, b = X_train.shape
X_train = X_train.reshape(a, b, 1)

out_neurons = 1
in_neurons=1
hidden_neurons = 300
length_of_sequences = 3

model = Sequential()
model.add(LSTM(hidden_neurons, batch_input_shape=(None, length_of_sequences, in_neurons), return_sequences=False))
model.add(Dense(out_neurons))
model.add(Activation("linear"))
model.compile(loss="mean_squared_error", optimizer="adam",)
early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])
pred_data = model.predict(X_test)
plt.plot(y_test, label='train')
plt.plot(pred_data, label='pred')
plt.legend(loc='upper left')
plt.show()
predp3=(pred_data>=0).reshape(len(y_test))
testp3=(y_test>=0).reshape(len(y_test))
a2=(predp3==testp3)
len(a2[a2==True])/len(a2)
# Out:
# Train on 616 samples, validate on 69 samples
# Epoch 1/10
# 616/616 [==============================] - 1s 2ms/step - loss: 0.0027 - val_loss: 0.0018
# Epoch 2/10
# 616/616 [==============================] - 0s 224us/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 3/10
# 616/616 [==============================] - 0s 275us/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 4/10
# 616/616 [==============================] - 0s 266us/step - loss: 0.0028 - val_loss: 0.0011
# Train on 616 samples, validate on 69 samples
# Epoch 1/10
# 616/616 [==============================] - 1s 1ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 2/10
# 616/616 [==============================] - 0s 235us/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 3/10
# 616/616 [==============================] - 0s 315us/step - loss: 0.0028 - val_loss: 0.0011
# 0.5680473372781065

# %%
from keras.callbacks import EarlyStopping
bitm3=ad.copy()#bitm["price"].copy()
#bitm3=(bitm3-bitm3.shift(1)).dropna()
bitm3=bitm3.reset_index()
bitm3=bitm3.drop("index",axis=1)
sss=0
(X_train, y_train), (X_test, y_test) = train_test_split(bitm3)
#m, n=X_train.shape
#X_train=X_train.reshape(m,n,1)
#m, n=X_test.shape
#X_test=X_test.reshape(m,n,1)
out_neurons = 1
in_neurons=2
hidden_neurons = 300
length_of_sequences = 3
for i in range(3):
    model = Sequential()
    model.add(LSTM(hidden_neurons, batch_input_shape=(None, length_of_sequences, in_neurons), return_sequences=False))
    model.add(Dense(out_neurons))
    model.add(Activation("linear"))
    model.compile(loss="mean_squared_error", optimizer="adam",)
    early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=0)
#for i in range(2):
    history = model.fit(X_train, y_train, batch_size=600, epochs=10, validation_split=0.1, callbacks=[early_stopping])
    pred_data = model.predict(X_test)
        #plt.plot(y_test, label='train')
        #plt.plot(pred_data, label='pred')
        #plt.legend(loc='upper left')
        #plt.show()
    predp3=(pred_data>=0).reshape(len(y_test))
    testp3=(y_test>=0).reshape(len(y_test))
    a2=(predp3==testp3)
    print(len(a2[a2==True])/len(a2))
    if len(a2[a2==True])/len(a2)>0.77:
        break
    sss+=len(a2[a2==True])/len(a2)
# Out:
# Train on 613 samples, validate on 69 samples
# Epoch 1/10
# 613/613 [==============================] - 34s 56ms/step - loss: 7.4633e-04 - val_loss: 0.0154
# Epoch 2/10
# 613/613 [==============================] - 0s 349us/step - loss: 6.0979e-04 - val_loss: 0.0161
# 0.5209580838323353
# Train on 613 samples, validate on 69 samples
# Epoch 1/10
# 613/613 [==============================] - 24s 39ms/step - loss: 0.0015 - val_loss: 0.0154
# Epoch 2/10
# 613/613 [==============================] - 0s 436us/step - loss: 6.9875e-04 - val_loss: 0.0163
# 0.5748502994011976
# Train on 613 samples, validate on 69 samples
# Epoch 1/10
# 613/613 [==============================] - 21s 35ms/step - loss: 8.1657e-04 - val_loss: 0.0151
# Epoch 2/10
# 613/613 [==============================] - 0s 351us/step - loss: 5.8696e-04 - val_loss: 0.0151
# 0.4311377245508982

# %%
sss
# Out:
# 6.964705882352942

# %%
model_json_str = model.to_json()
open('bitcoin-favoRT1-75%.json', 'w').write(model_json_str)
model.save_weights('bitcoin-favoRT1-75.h5');

# %%
ad.plot()

# %%
#bitm3
