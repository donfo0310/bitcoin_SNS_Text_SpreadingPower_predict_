# %%
import pandas as pd
df = pd.read_csv("/Users/donfuo/twitter-bitdata/bit-2018-0601-0427.csv",names=["username","date","RT","Favo","text","Geo","mention","hashtag","id","permalink"])

# %%
import pandas as pd
import MeCab as mcb
df = pd.read_csv("/Users/donfuo/csvall.csv",names=["username","date","RT","Favo","text","Geo","mention","hashtag","id","permalink","trash","t2"])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (0,2,3,8,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#f = pd.read_csv("csvall.csv",engine='python')#names=["username","date","RT","Favo","text","Geo","mention","hashtag","id","permalink"])

# %%
from pandas.compat import StringIO
df = pd.read_csv("/Users/donfuo/csvall.csv",names=["username","date","RT","Favo","text","Geo","mention","hashtag","id","permalink","trash","t2"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
# Exception ignored in: 'zmq.backend.cython.message.Frame.__dealloc__'
# Traceback (most recent call last):
#   File "zmq/backend/cython/checkrc.pxd", line 12, in zmq.backend.cython.checkrc._check_rc
# KeyboardInterrupt
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (0,2,3,8,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#df=df.loc[:,['date','RT','Favo','text','permalink']]
import pandas as pd
import MeCab as mcb
df = pd.read_csv("元データ")

# %%
#df.loc[1,'hashtag'].isnull()
df[df['text'].duplicated()]
# Out:
#                date      date.1  RT  Favo  \
# 9        2016-01-01  2016-01-01   0     0
# 51       2016-01-01  2016-01-01   0     0
# 61       2016-01-01  2016-01-01   0     0
# 62       2016-01-01  2016-01-01   0     0
# 63       2016-01-01  2016-01-01   0     1
# 64       2016-01-01  2016-01-01   0     0
# 65       2016-01-01  2016-01-01   0     1
# 66       2016-01-01  2016-01-01   0     0
# 67       2016-01-01  2016-01-01   0     0
# 68       2016-01-01  2016-01-01   0     0
# 69       2016-01-01  2016-01-01   0     0
# 70       2016-01-01  2016-01-01   0     0
# 71       2016-01-01  2016-01-01   0     1
# 72       2016-01-01  2016-01-01   0     0
# 73       2016-01-01  2016-01-01   1     0
# 74       2016-01-01  2016-01-01   0     0
# 75       2016-01-01  2016-01-01   0     0
# 76       2016-01-01  2016-01-01   1     0
# 77       2016-01-01  2016-01-01   0     0
# 78       2016-01-01  2016-01-01   0     1
# 79       2016-01-01  2016-01-01   0     0
# ...

# %%
vc=df['text'].value_counts().index[df['text'].value_counts()>1100]

# %%
vc=vc.tolist()

# %%
df['text'].value_counts()
# Out:
# investment clubでは、少額で始められるビットコイン投資術（仮想通貨）を当倶楽部で学ばれる方限定で教えています。仮想通貨とはIT技術を利用して生み出された通貨のこと。実際に手にとることはできない、形のない通貨です。                                                                              3504
# 仮想通貨の代表格：ビットコイン 「ビットコイン」名前を耳にした人も多いはず。 現在の日本では主に投資、投機目的で用いられています。 リアルタイムで変動する相場で円ドルやドルなどと交換することができる仮想通貨は、通常の為替取引と同様に、日々実際の通貨と取引されているのです。                                                       3358
# サーバ継続のためモナコイン、ビットコインの寄付をよろしくお願いします。 mona MHZDVZAEiJRH7mb2mrhYsbKsp7MKJQCWSs BTC 161k4HDY8B19cWp7j8V5cescrKdLuKBhM9                                                                             2589
# ビットクラブ。 もうやってる人はRT。 やりたいけど、まだやってない人はファボ。 # ビットコイン # マイニング                                                                                                                                      2424
# 一緒に暗号通貨勉強しましょう。 もっと早くに知っておけば よかったと思う前に 行動に移しましょう！！！ 今知ることが出来れば 5年後10年後のあなたの生活は 絶対に変わりますよ。 時間もビットコインも有限です 有限だからこそ価値がある。 パートナー募集中です。 DMまで。                                                       2356
# ...

# %%
vcc=[]
for i in range(len(vc)):
    if len(vc[i])>70:
        vcc.append(vc[i])
# Out:
# 1038294

# %%
vd.to_csv("重複データ削除済みテキストデータ")

# %%
vd=df[df['text'].apply(lambda s:s not in vcc)]
vd['text'].value_counts()
# Out:
# ビットクラブ。 もうやってる人はRT。 やりたいけど、まだやってない人はファボ。 # ビットコイン # マイニング                                                                                                                                      2424
# 今年の三月四日に金融庁がビットコインを貨幣と定義したことがニュースで話題になりました→詳細はDMで！                                                                                                                                             1754
# とりあえず、 将来が不安ならビットコインを買う もっと稼ぎたいなら マイニングする。 今はマイニング事業が 硬いですね。 ビットクラブ最高、                                                                                                                         1474
# ビットコイン                                                                                                                                                                                         1221
# 3:33気味悪                                                                                                                                                                                        1184
# ...

# %%
#len(vcc)
vd=vd[vd['text'].apply(lambda s:s not in vc)]

# %%
len(vd)
# Out:
# 1205108

# %%
j=i
for i in range(j,len(df)):
    if df.loc[i,'text'] in vcc:
        df=df.drop(i,axis=0)
    if i%50000==0:
        print(i)
# Out:
# 100000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-781c89f7e8ea> in <module>()
#       2 for i in range(j,len(df)):
#       3     if df.loc[i,'text'] in vcc:
# ----> 4         df=df.drop(i,axis=0)
#       5     if i%50000==0:
#       6         print(i)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    2561             else:
# ...

# %%
#len(df)
# Out:
# 1251008

# %%
len(df[df['permalink'].isnull()])
# Out:
# 195

# %%
df=df.drop(2535432)
https://twitter.com/I_wanna_be_all/status/1072676723098116096

# %%
dt=df.loc[2,'permalink']

# %%
dt
# Out:
# 'https://twitter.com/RMM0304/status/704450646678728704'

# %%
import re

# %%
search_result = re.search('/[0-9]{16,21}', dt)

# %%
search_result=re.sub('/status/[0-9]+','', dt)

# %%
search_result
# Out:
# 'https://twitter.com/RMM0304'

# %%
df=df.loc[:,['date','text','permalink']]

# %%
df=df.drop(df[df['permalink'].isnull()],axis=1)

# %%
#df
import requests
get_url_info = requests.get(search_result)

# %%
data=data.dropna(subset=['permalink'])

# %%
data[data.iloc[:,5]!=0]
# Out:
#                   date RT Favo  \
# date
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  1    2
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    1
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    1
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# 2016-01-01  2016-01-01  0    0
# ...

# %%
#data.iloc[i,:]
#data.to_csv('元データ')
#data.iloc[:,4]

# %%
i=0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-397d543883c5> in <module>()
# ----> 1 i
#
# NameError: name 'i' is not defined

# %%
import requests
import time
count=0
j=i
reg = re.compile('/status/[0-9]+')
reg1=re.compile('''<span class="ProfileNav-label" aria-hidden="true">フォロワー</span>
            <span class="u-hiddenVisually">フォロワー</span>
          <span class="ProfileNav-value" data-count=[0-9]+''')
reg2=re.compile('[0-9]+')
for i in range(j,len(data)):
    search_result=reg.sub('', data.iloc[i,4])
    #print(search_result)
    try:
        get_url_info = requests.get(search_result)
        time.sleep(0.4)
    except KeyboardInterrupt:
        raise
    except:
        count+=1
    se=reg1.search(get_url_info.text)
    if se!=None:
        data.iloc[i,5]=int(reg2.search(se.group(0)).group(0))

# %%
import requests
count=0
j=i

for i in range(j,len(data)):
    search_result=re.sub('/status/[0-9]+','', data.iloc[i,4])
    #print(search_result)
    try:
        get_url_info = requests.get(search_result)
    except:
        count+=1
    se=re.search('''<span class="ProfileNav-label" aria-hidden="true">フォロワー</span>
            <span class="u-hiddenVisually">フォロワー</span>
          <span class="ProfileNav-value" data-count=[0-9]+''',get_url_info.text)
    if se!=None:
        data.iloc[i,5]=int(re.search('[0-9]+',se.group(0)).group(0))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-53532c34ddd1> in <module>()
#      13           <span class="ProfileNav-value" data-count=[0-9]+''',get_url_info.text)
#      14     if se!=None:
# ---> 15         data.iloc[i,5]=int(re.search('[0-9]+',se.group(0)).group(0))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
# ...

# %%
tex=get_url_info.text
se=re.search('''<span class="ProfileNav-label" aria-hidden="true">フォロワー</span>
            <span class="u-hiddenVisually">フォロワー</span>
          <span class="ProfileNav-value" data-count=[0-9]+''',tex)
#bittex=df['text']

# %%
print(se)
# Out:
# <_sre.SRE_Match object; span=(44888, 45062), match='<span class="ProfileNav-label" aria-hidden="true">

# %%
re.search('[0-9]+',se.group(0)).group(0)
# Out:
# '8268'

# %%
for i in range(10):#len(bittex):
    if len(bittex[i])>100:
        print(bittex[i])
        print(i)

# %%
bittex

# %%
df['Favo'].astype(int)

# %%
df=df.drop(0,axis=0)
df=df.reset_index()

# %%
df=df.drop('index',axis=1)

# %%
newT=df[(df['Favo'].astype(int)>0) | (df['RT'].astype(int)>0)]

# %%
newT.to_csv("twitter_data_favo1.csv")

# %%
data=df

# %%
newT[['date','text']].to_csv("twitter_data_favo1.csv")

# %%
newT=newT[['date','text']]

# %%
newT

# %%
import random

# %%
random.randrange(2535419)

# %%
newT['PN']=5

# %%
newT

# %%
for i in range(1000):
    a=random.randrange(802969)
    if newT.loc[a,'PN'] == 5:
        print(newT.loc[a,'text'])
        b=input()
        newT.loc[a,'PN']=b

# %%
newT=newT.reset_index()

# %%
newT=newT.drop('index',axis=1)

# %%
newT.loc[5,'PN']=5

# %%
vd
# Out:
#                date      date.1  RT  Favo  \
# 0        2016-01-01  2016-01-01   0     0
# 2        2016-01-01  2016-01-01   1     2
# 3        2016-01-01  2016-01-01   0     0
# 4        2016-01-01  2016-01-01   0     0
# 5        2016-01-01  2016-01-01   0     0
# 6        2016-01-01  2016-01-01   0     0
# 8        2016-01-01  2016-01-01   0     0
# 9        2016-01-01  2016-01-01   0     0
# 11       2016-01-01  2016-01-01   0     0
# 12       2016-01-01  2016-01-01   0     0
# 14       2016-01-01  2016-01-01   0     1
# 17       2016-01-01  2016-01-01   0     0
# 18       2016-01-01  2016-01-01   0     0
# 20       2016-01-01  2016-01-01   0     0
# 21       2016-01-01  2016-01-01   0     1
# 22       2016-01-01  2016-01-01   0     0
# 24       2016-01-01  2016-01-01   0     0
# 25       2016-01-01  2016-01-01   0     0
# 27       2016-01-01  2016-01-01   0     0
# 28       2016-01-01  2016-01-01   0     0
# 30       2016-01-01  2016-01-01   0     0
# ...

# %%
import pandas as pd
import MeCab as mcb
#df = pd.read_csv("twitter_data_favo1.csv")
df=vd
dic=pd.read_csv("PN-pojinega.csv",encoding='cp932')
#df = pd.read_csv("csvall.csv",engine='python')#names=["username","date","RT","Favo","text","Geo","mention","hashtag","id","permalink"])
m = mcb.Tagger('-Ochasen')
text=df.loc[0:,['date','text']]
text=text.reset_index()
text=text.drop_duplicates()

day=[]
for i in range(0,len(text['date'])):
    if text.at[i,'date'][:10] not in day:
        day.append(text.at[i,'date'][:10])
days = pd.DataFrame(day,columns={'day'})
days['sum']=0

m.parse('')
node = m.parseToNode(text.at[0,'text'])
keywords = []
value = []

f=text.at[0,'date'][:10]
fc=0
summ=0
count=0
for i in range(0,len(text['text'])):
    if i==100000:
        print(days)
    summ=0
    count=0
    node = m.parseToNode(text.at[i,'text'])
    
    while node:
        if node.feature.split(",")[0] == u"名詞" or node.feature.split(",")[0] == u"形容詞" or node.feature.split(",")[0] == u"動詞" or node.feature.split(",")[0] == u"副詞":
            if len(dic.loc[dic['言葉']== node.surface,'極性値'])==1:
                summ=summ+float(dic.loc[dic['言葉']== node.surface,'極性値'].values.tolist()[0])
                count=count+1
                #keywords[fc-1].append(node.surfac
                
        node = node.next
    if count!=0:
        #print("一文の合計"+str(summ))
        days.loc[days['day']==text.at[i,'date'][:10],'sum'] = days.loc[days['day']==text.at[i,'date'][:10],'sum'].astype(float)+summ/count
        #print(days.loc[days['day']==text.at[i,'date'][:10],'sum'])
    #text[i]['sum']=summ/count
    f=text.at[i,'date'][:10]
    if f!=text.at[i+1,'date'][:10]:
        #print("1テキスト完了")
        #print(days.loc[days['day']==f,'sum'])
        #print(len(text.loc[text['date']==f,'date']))
        days.loc[days['day']==f,'sum']=days.loc[days['day']==f,'sum']/len(text.loc[text['date']==f,'date'])
        
#dic.loc[dic['言葉']== "喜び",'極性値']
#te=keywords[:20]
#len(te)
days.to_csv("del-duplicate-newdata")
#days.to_csv("twitter_data_favo1.csv")
# Out:
#             day       sum
# 0    2016-01-01 -0.427337
# 1    2016-01-02 -0.423968
# 2    2016-01-03 -0.391909
# 3    2016-01-04 -0.406785
# 4    2016-01-05 -0.380087
# 5    2016-01-06 -0.410771
# 6    2016-01-07 -0.378915
# 7    2016-01-08 -0.401170
# 8    2016-01-09 -0.416980
# 9    2016-01-10 -0.388643
# 10   2016-01-11 -0.385303
# 11   2016-01-12 -0.397598
# 12   2016-01-13 -0.395350
# 13   2016-01-14 -0.391327
# 14   2016-01-15 -0.319264
# 15   2016-01-16 -0.403165
# 16   2016-01-17 -0.360588
# 17   2016-01-18 -0.367479
# 18   2016-01-19 -0.414255
# 19   2016-01-20 -0.369318
# 20   2016-01-21 -0.391716
# 21   2016-01-22 -0.393696
# 22   2016-01-23 -0.341930
# 23   2016-01-24 -0.401863
# 24   2016-01-25 -0.024638
# 25   2016-01-26 -0.372096
# 26   2016-01-27 -0.383892
# 27   2016-01-28 -0.327690
# 28   2016-01-29 -0.399541
# 29   2016-01-30 -0.393240
# ..          ...       ...
# 853  2018-05-03  0.000000
# 854  2018-05-04  0.000000
# 855  2018-05-05  0.000000
# ...

# %%
days.to_csv("del-duplicate-newdata")

# %%
#data=data.drop(0)
days
# Out:
#             day         sum
# 0    2016-01-01   -0.427337
# 1    2016-01-02   -0.423968
# 2    2016-01-03   -0.391909
# 3    2016-01-04   -0.406785
# 4    2016-01-05   -0.380087
# 5    2016-01-06   -0.410771
# 6    2016-01-07   -0.378915
# 7    2016-01-08   -0.401170
# 8    2016-01-09   -0.416980
# 9    2016-01-10   -0.388643
# 10   2016-01-11   -0.385303
# 11   2016-01-12   -0.397598
# 12   2016-01-13   -0.395350
# 13   2016-01-14   -0.391327
# 14   2016-01-15   -0.319264
# 15   2016-01-16   -0.403165
# 16   2016-01-17   -0.360588
# 17   2016-01-18   -0.367479
# 18   2016-01-19   -0.414255
# 19   2016-01-20   -0.369318
# 20   2016-01-21   -0.391716
# 21   2016-01-22   -0.393696
# 22   2016-01-23   -0.341930
# 23   2016-01-24   -0.401863
# 24   2016-01-25   -0.024638
# 25   2016-01-26   -0.372096
# 26   2016-01-27   -0.383892
# 27   2016-01-28   -0.327690
# 28   2016-01-29   -0.399541
# 29   2016-01-30   -0.393240
# ..          ...         ...
# 853  2018-05-03   -0.380672
# ...

# %%
data=data.reset_index(drop=True)

# %%
for i in range(0,len(data['date'])):
    data.at[i,'date']=data.at[i,'date'][:10]

# %%
data['follower']=0

# %%
day=[]
for i in range(0,len(cpd['date'])):
    if cpd.at[i,'date'][:10] not in day:
        day.append(cpd.at[i,'date'][:10])
days = pd.DataFrame(day,columns={'day'})
days
# Out:
#             day
# 0    2016-03-01
# 1    2016-02-29
# 2    2016-02-28
# 3    2016-02-27
# 4    2016-02-26
# 5    2016-02-25
# 6    2016-02-24
# 7    2016-02-23
# 8    2016-02-22
# 9    2016-02-21
# 10   2016-02-20
# 11   2016-02-19
# 12   2016-02-18
# 13   2016-02-17
# 14   2016-02-16
# 15   2016-02-15
# 16   2016-02-14
# 17   2016-02-13
# 18   2016-02-12
# 19   2016-02-11
# 20   2016-02-10
# 21   2016-02-09
# 22   2016-02-08
# 23   2016-02-07
# 24   2016-02-06
# 25   2016-02-05
# 26   2016-02-04
# 27   2016-02-03
# 28   2016-02-02
# 29   2016-02-01
# ..          ...
# 853  2018-05-31
# 854  2018-05-30
# 855  2018-05-29
# 856  2018-05-28
# 857  2018-05-27
# 858  2018-05-26
# 859  2018-05-25
# 860  2018-05-24
# 861  2018-05-23
# 862  2018-05-22
# 863  2018-05-21
# 864  2018-05-20
# 865  2018-05-19
# 866  2018-05-18
# 867  2018-05-17
# 868  2018-05-16
# 869  2018-05-15
# 870  2018-05-14
# 871  2018-05-13
# 872  2018-05-12
# 873  2018-05-11
# 874  2018-05-10
# 875  2018-05-09
# ...

# %%
days['RT']=0
days['Favo']=0

# %%
days.index=pd.to_datetime(days['day'])

# %%
days.loc[pd.to_datetime(data.at[0,'date']),'RT']=0

# %%
data.index=pd.to_datetime(data['date'])

# %%
data=text

# %%
data.index=range(len(data))

# %%
for i in range(0,len(data['date'])):
    days.loc[pd.to_datetime(data.at[i,'date']),'RT']+=int(data.at[i,'RT'])
    days.loc[pd.to_datetime(data.at[i,'date']),'Favo']+=int(data.at[i,'Favo'])

# %%
days.loc[days.index[0],'tweetnum']

# %%
data.loc[days.index[0]==data.index,'RT'].astype(int).sum()

# %%
#days.loc[pd.to_datetime(data.at[0,'date']),'RT']
for i in range(0,len(days)):
    days.loc[days.index[i],'tweetnum']=len(data[days.index[i]==data.index])
    days.loc[days.index[i],'RT']=data.loc[days.index[i]==data.index,'RT'].astype(int).sum()
    days.loc[days.index[i],'Favo']=data.loc[days.index[i]==data.index,'Favo'].astype(int).sum()

# %%
days.to_csv('new_f-r-n.csv')

# %%
days['tweetnum']=0

# %%
data.index=pd.to_datetime(data['date'])

# %%
data=data.sort_index()
data=data.drop_duplicates()

# %%
len(data)
# Out:
# 1251104

# %%
days=days.sort_index()

# %%
days

# %%
days['tweetnum']=0
for i in range(len(days)):
    days.at[i,'tweetnum']=len(data[data.index==days.at[i,'day']])

# %%
#data[data.index==days.index[600]]
days.at[0,days.index(0)]

# %%
days.index=range(len(days))
days#['2016-01-01']

# %%
data[data.index==days.at[0,'day']]

# %%
days.to_csv('RT-Favo-num.csv')

# %%
len(data)

# %%
#text=df.loc[0:,['date','text','RT','Favo']]
#text=text.reset_index()
text.index=pd.to_datetime(text['date'])
text=text.drop_duplicates()

# %%
len(text)

# %%
text=text.sort_index()

# %%
text=text.drop_duplicates()

# %%
text=text.drop('index',axis=1)

# %%
data=text

# %%
text=text[~text.duplicated()]

# %%
text.index=range(len(text['date']))

# %%
for i in range(0,len(text['date'])):
    text.at[i,'date']=text.at[i,'date'][:10]
len(text[text['date']==text.at[1,'date'][:10]])

# %%
len(text)

# %%
#text.index=pd.to_datetime(text['date'])
text=text[~text['text'].duplicated()]

# %%
text.duplicated()

# %%
#days

# %%
#very positive 4 positive 3 neutral 2 negative 1 very negative0
import random
for i in range(100):
    a=random.randrange(len(text))
    if text.loc[a,'PN'] == 5:
        print(text.loc[a,'date'])
        print(text.loc[a,'text'])
        print('--------------------------------')
        b=input()
        text.loc[a,'PN']=b
        new=new.append(text.loc[a,:].copy())
new.to_csv('PNビットの教師データ.csv')

# %%
text.loc[1,'PN']=b#2が真ん中

# %%
text.loc[:,'PN']=5

# %%
text.loc[1,'PN']==5

# %%
text.index=range(len(text))

# %%
#text

# %%
new=pd.DataFrame()

# %%
new=new.append(text.loc[1,:])
new

# %%
text.loc[1,:]

# %%
new=new.drop(1)

# %%
new.to_csv('PNビットの教師データ.csv')

# %%
import re
import MeCab
tagger = MeCab.Tagger("-d /usr/local/lib/mecab/dic/mecab-ipadic-neologd/")
 
def nouns_extract(line):
    keyword=[]
    node = tagger.parseToNode(line).next
    while node:
        #node = re.sub(r'[0123456789０１２３４５６７８９！＠＃＄％＾＆\-|\\＊\“（）＿■×※⇒—●(：〜＋=)／*&^%$#@!~`){}…\[\]\"\'\”:;<>?＜＞？、。・,./『』【】「」→←○]+', "", node)
        if node.feature.split(",")[0] == u"名詞" or node.feature.split(",")[0] == u"動詞":
            keyword.append(node.surface)
        node = node.next
    keyword = str(keyword).replace("', '"," ")
    keyword = keyword.replace("\'","")
    keyword = keyword.replace("[","")
    keyword = keyword.replace("]","")
    return keyword

# %%
import pandas as pd
df = pd.read_csv("PNビットの教師データ.csv")
text = pd.read_csv('twitter_data_favo1.csv')

# %%
text

# %%
df["text_wakati"] = list(map(lambda text:nouns_extract(text) , df.text))

# %%
text["text_wakati"] = list(map(lambda text:nouns_extract(text) , text.text))

# %%
text

# %%
sentences2 = [token.split(" ") for token in text.text_wakati]

model = Word2Vec(sentences2, 
                 size=100,
                 window=5, 
                 min_count=5,
                 workers=2)

# %%
len(sentences2)

# %%
sentences2 = [token.split(" ") for token in text.text_wakati]
len(sentences2)

# %%
from gensim.models.word2vec import Word2Vec
from gensim.models import word2vec
model = Word2Vec(sentences2, 
                 size=100,
                 window=5, 
                 min_count=5,
                 workers=2)

# %%
res=model.most_similar(positive='上昇',topn=10)
for re in res:
    print(res[0],'\t',res[1])

# %%
model.most_similar('情報工学')

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline
def tsne_plot(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    for word in model.wv.vocab:
        tokens.append(model[word])
        labels.append(word)
    
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()

# %%
tsne_plot(model)

# %%
import numpy
from gensim.models.keyedvectors import KeyedVectors
def main(model):
    for line in f:
        community_words = line.rstrip().split(' ')
        community_name = ''.join(community_words)
        try:
                community_vec = text_to_vec(community_words, model)
                community_vec = normalize(community_vec)
                numpy.savetxt('./vec/' + community_name, community_vec)
        except:
                pass
        
def text_to_vec(words, model):
    word_vecs = []
    for word in words:
        try:
            word_vecs.append(model[word])
        except:
            pass
    if len(word_vecs) == 0:
        return None
    text_vec = numpy.zeros(word_vecs[0].shape, dtype = word_vecs[0].dtype)
    for word_vec in word_vecs:
        text_vec = text_vec + word_vec
    return text_vec
def normalize(vec):
    return vec / numpy.linalg.norm(vec)

# %%
normalize(text_to_vec(sentences2[1],model))

# %%
from gensim import models

# gensim にクチコミを登録
# クチコミに会社名を付与するため、参考記事で実装されていた拡張クラスを使っています
sentences = sentences2

# doc2vec の学習条件設定
# alpha: 学習率 / min_count: X回未満しか出てこない単語は無視
# size: ベクトルの次元数 / iter: 反復回数 / workers: 並列実行数
model = models.Doc2Vec(alpha=0.025, min_count=5,
                       size=100, iter=20, workers=4)

# doc2vec の学習前準備(単語リスト構築)
model.build_vocab(sentences)

# Wikipedia から学習させた単語ベクトルを無理やり適用して利用することも出来ます
# model.intersect_word2vec_format('./data/wiki/wiki2vec.bin', binary=True)

# 学習実行
model.train(sentences)

# セーブ
model.save('./data/doc2vec.model')

# %%
num_features = 200     # Word vector dimensionality
min_word_count = 20   # Minimum word count
num_workers = 40       # Number of threads to run in parallel
context = 10          # Context window size
downsampling = 1e-3   # Downsample setting for frequent words

print ("Training Word2Vec model...")
# Train Word2Vec model.
model = Word2Vec(sentences2, workers=num_workers, hs = 0, sg = 1, negative = 10, iter = 25,\
            size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling, seed=1)

model_name = str(num_features) + "features_" + str(min_word_count) + "minwords_" + str(context) + "context_len2alldata"
model.init_sims(replace=True)

# %%
model.save(model_name)

# %%
import numpy as np

# %%
def get_vector(text):
    sum_vec = np.zeros(100)
    word_count = 0
    node = tagger.parseToNode(text)
    while node:
        fields = node.feature.split(",")
        # 名詞、動詞、形容詞に限定
        if fields[0] == '名詞' or fields[0] == '動詞':
            sum_vec += model.wv[node.surface]
            word_count += 1
        node = node.next
    return sum_vec / word_count

# %%
get_vector(text.loc[1,'text'])

# %%
model['情報工学']

# %%
sentences2[100]

# %%
data=pd.read_csv('PNビットの教師データ.csv')

# %%
dat=data.loc[:,['text','PN']]

# %%
import re
import MeCab
tagger = MeCab.Tagger("-d /usr/local/lib/mecab/dic/mecab-ipadic-neologd/")
 
def nouns_extract(line):
    keyword=[]
    node = tagger.parseToNode(line).next
    while node:
        #node = re.sub(r'[0123456789０１２３４５６７８９！＠＃＄％＾＆\-|\\＊\“（）＿■×※⇒—●(：〜＋=)／*&^%$#@!~`){}…\[\]\"\'\”:;<>?＜＞？、。・,./『』【】「」→←○]+', "", node)
        if node.feature.split(",")[0] == u"名詞" or node.feature.split(",")[0] == u"動詞":
            keyword.append(node.surface)
        node = node.next
    keyword = str(keyword).replace("', '"," ")
    keyword = keyword.replace("\'","")
    keyword = keyword.replace("[","")
    keyword = keyword.replace("]","")
    return keyword

# %%
dat["text_wakati"] = list(map(lambda text:nouns_extract(text) , dat.text))

# %%
sentences = [token.split(" ") for token in dat.text_wakati]

# %%
dat

# %%
a=normalize(text_to_vec(sentences2,model))

# %%
def text_to_vec(words, model):
    word_vecs = []
    for word in words:
        try:
            word_vecs.append(model[word])
        except:
            pass
    if len(word_vecs) == 0:
        return None
    text_vec = numpy.zeros(word_vecs[0].shape, dtype = word_vecs[0].dtype)
    for word_vec in word_vecs:
        text_vec = text_vec + word_vec
    return normalize(text_vec)
def normalize(vec):
    return vec / numpy.linalg.norm(vec)

# %%
b=len(sentences)
vec=[]
for i in range(b):
    vec.append(text_to_vec(sentences[i],model))

# %%
a=text_to_vec(sentences,model)

# %%
vec=pd.DataFrame(vec)

# %%
tvec=pd.concat([vec,dat['PN']],axis=1)

# %%
tvec[:,:99]

# %%
from sklearn.svm import SVC
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import accuracy_score

# %%
X=np.array(vec)
y=np.array(dat['PN'])
param_grid={"gamma":np.logspace(-2,0,10),"C":np.logspace(0,3,10)}
gs=GridSearchCV(SVC(kernel="rbf"),param_grid).fit(X,y)
#param_grid={"C":np.logspace(0,2,10)}
#gs=GridSearchCV(SVC(kernel="linear"),param_grid).fit(X,y)
clf=gs.best_estimator_

# quantitative evaluation
print ("best parameters:",gs.best_params_)
print ("CV score:",gs.best_score_)

# %%
#vec[0]
vec.shape

# %%
pre=clf.predict(np.array(vec[:10]))

# %%
pre

# %%
np.array(vec.loc[0,:]).shape

# %%
pre
accuracy_score(np.array(tvec['PN']), pre)

# %%
tvec

# %%
len(sentences2)

# %%
len(df)

# %%
b=len(sentences2)
vec3=[]
for i in range(b):
    vec3.append(text_to_vec(sentences2[i],model))

# %%
vecc=pd.DataFrame(vec2)

# %%
vec2=np.array(vec2)

# %%
vec.shape

# %%
#c_vec.reshape(801902,100)
type(vec)

# %%
vec2

# %%
pre2=clf.predict(c_vec[0:10])

# %%
a=vec2[0].shape
for i in range(0,len(vec2)):
    if a!=vec2[i].shape:
        print(vec2[i])

# %%
c_vec=vec2.copy()

# %%
c_vec=vec3.copy()
del_list=[]
i=0
c=0
a=vec2[i].shape
for i in range(len(c_vec)):
    try:
        a=c_vec[i].shape
    except:
        del_list.append(i)
        c+=1
        c_vec = np.delete(c_vec, i, 0)
        print(i)

# %%
print(vec2[2763])

# %%
c

# %%
vecc

# %%
len(c_vec)
type(c_vec)

# %%
type(vec[0])

# %%
#cpd=pd.concat([cpd, pd.DataFrame(c_vec[2])], axis=1)
cpd

# %%
cpd=pd.DataFrame(c_vec[0])

# %%
c_list=c_vec.tolist()

# %%
#pd.DataFrame(c_list)
cpd=pd.DataFrame(c_vec[0])
for i in range(1,len(c_vec)):
    cpd=pd.concat([cpd, pd.DataFrame(c_vec[i])], axis=1)

# %%
#text.to_csv('wakati-data-8万件')
cpd

# %%
#for i in range(len(c_vec)):
#    c_vec[i]=c_vec.tolist()
cpd=cpd.T
cpd.to_csv('pandasのword2vecデータ8万件')
#pre=clf.predict(np.array(cpd[:10]))

del_list=[]

# %%
cpd=pd.DataFrame(c_vec)
cpd

# %%
import re
import MeCab
import pandas as pd
from gensim.models.word2vec import Word2Vec
from gensim.models import word2vec
import numpy as np
from sklearn.svm import SVC
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import accuracy_score

tagger = MeCab.Tagger("-d /usr/local/lib/mecab/dic/mecab-ipadic-neologd/")
 
def nouns_extract(line):
    keyword=[]
    node = tagger.parseToNode(line).next
    while node:
        #node = re.sub(r'[0123456789０１２３４５６７８９！＠＃＄％＾＆\-|\\＊\“（）＿■×※⇒—●(：〜＋=)／*&^%$#@!~`){}…\[\]\"\'\”:;<>?＜＞？、。・,./『』【】「」→←○]+', "", node)
        if node.feature.split(",")[0] == u"名詞" or node.feature.split(",")[0] == u"動詞":
            #print(node.surface)
            tx = re.sub(r'[0123456789０１２３４５６７８９！＠＃＄％＾＆\-|\\＊\“（）＿■×※⇒—●(：〜＋=)／*&^%$#@!~`){}…\[\]\"\'\”:;<>?＜＞？、。・,./『』【】「」→←○]+', "", node.surface)
            
            keyword.append(tx)#node.surface)
        node = node.next
    keyword = str(keyword).replace("', '"," ")
    keyword = keyword.replace("\'","")
    keyword = keyword.replace("[","")
    keyword = keyword.replace("]","")
    return keyword
        
def text_to_vec(words, model):
    word_vecs = []
    for word in words:
        try:
            word_vecs.append(model[word])
        except:
            pass
    if len(word_vecs) == 0:
        return None
    text_vec = np.zeros(word_vecs[0].shape, dtype = word_vecs[0].dtype)
    for word_vec in word_vecs:
        text_vec = text_vec + word_vec
    return normalize(text_vec)
def normalize(vec):
    return vec / np.linalg.norm(vec)


df = pd.read_csv("PNビットの教師データ.csv")
#text = pd.read_csv('twitter_data_favo1.csv')
text = pd.read_csv("重複データ削除済みテキストデータ")
df["text_wakati"] = list(map(lambda text:nouns_extract(text) , df.text))
text["text_wakati"] = list(map(lambda text:nouns_extract(text) , text.text))
sentences = [token.split(" ") for token in df.text_wakati]
sentences2 = [token.split(" ") for token in text.text_wakati]


model = Word2Vec(sentences2, 
                 size=100,
                 window=5, 
                 min_count=5,
                 workers=2)

vec=[]
for i in range(len(sentences)):
    vec.append(text_to_vec(sentences[i],model))
vec=pd.DataFrame(vec)
df=pd.concat([vec,df],axis=1)

X=np.array(vec)
y=np.array(df['PN'])
param_grid={"gamma":np.logspace(-2,0,10),"C":np.logspace(0,3,10)}
gs=GridSearchCV(SVC(kernel="rbf"),param_grid).fit(X,y)
#param_grid={"C":np.logspace(0,2,10)}
#gs=GridSearchCV(SVC(kernel="linear"),param_grid).fit(X,y)
clf=gs.best_estimator_

# quantitative evaluation
print ("best parameters:",gs.best_params_)
print ("CV score:",gs.best_score_)
pre=clf.predict(np.array(vec))
accuracy_score(np.array(df['PN']), pre)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# ...

# %%
pre
# Out:
# array([3, 3, 2, 3, 2, 2, 3, 3, 2, 1, 1, 2, 3, 1, 3, 2, 3, 1, 1, 4, 2, 0, 3,
#        2, 2, 2, 3, 1, 3, 2, 2, 3, 2, 2, 3, 3, 3, 2, 3, 1, 2, 4, 2, 0, 2, 1,
#        2, 2, 2, 3, 2, 3, 2, 1, 4, 3, 4, 3, 2, 2, 4, 1, 2, 2, 1, 2, 1, 2, 2,
#        3, 1, 3, 4, 0, 3, 1, 1, 1, 4, 3, 1, 1, 2, 3, 1, 0, 4, 3, 4, 1, 4, 2,
#        1, 2, 2, 3, 1, 0, 1, 1, 1, 1, 4, 2, 2, 3, 3, 4, 2, 1, 1, 3, 2, 1, 1,
#        2, 1, 4, 1, 3, 3, 2, 2, 3, 2, 2, 2, 1, 2, 2, 2, 2, 3, 3, 4, 2, 3, 2,
#        1, 0, 3, 4, 2, 3, 1, 0, 3, 4, 2, 3, 1, 2, 3, 2, 2, 2, 2, 1, 4, 0, 3,
#        0, 3, 4, 2, 2, 1, 2, 4, 1, 4, 1, 0, 2, 2, 3, 3, 0, 1, 3, 4, 3, 4, 4,
#        1, 3, 2, 1, 2, 2, 2, 4, 2, 1, 4, 3, 1, 2, 1, 3, 1, 3, 3, 1, 0, 0, 1,
#        2, 1, 3, 2, 2, 1, 1, 1, 3, 1, 3, 1, 2, 1, 3, 3, 2, 2, 3, 2, 2, 2, 4,
#        3, 2, 1, 3, 2, 3, 1, 1, 3, 2, 4, 3, 4, 2, 1, 1, 1, 3, 2, 2, 1, 1, 3,
#        0, 2, 3, 3, 3, 2, 0, 3, 3, 2, 1, 1, 2, 1, 2, 1, 1, 2, 2, 1, 2, 3, 2,
# ...

# %%
vec3=[]
for i in range(len(sentences2)):
    #ans=pd.concat([ans,pd.DataFrame(text_to_vec(sentences2[0],model)).T],axis=1)
    vec3.append(text_to_vec(sentences2[i],model))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:34: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
#vec_=pd.DataFrame(vec3)
#vec.shape
c_vec=vec3.copy()
del_list=[]
i=0
c=0
#a=vec2[i].shape
for i in range(len(c_vec)):
    try:
        a=c_vec[i].shape
    except:
        del_list.append(i)
        c+=1
        #text = text.drop(i, axis=0)
        c_vec = np.delete(c_vec, i, 0)

# %%
print(type(c_vec))
print(c_vec.shape, c_vec.dtype)

# %%
for i, row in enumerate(np.array(vec3)):
    if len(row) != 100:
        print(i, len(row))

# %%
#l

# %%
l=list(range(100))
ncols = 100
df = pd.DataFrame([
list(row)[:ncols] + [np.nan] * max(0, len(row) - ncols)
if np.ndim(row) == 1 else l 
for row in vec3
])
df
# Out:
#                0         1         2         3         4         5         6   \
# 0       -0.010809 -0.073932 -0.081632 -0.113499 -0.098633 -0.006557 -0.160446
# 1       -0.032185  0.053264  0.008913  0.145795 -0.002327  0.062933  0.049818
# 2       -0.029259  0.113036 -0.018587 -0.039526 -0.146289 -0.026302 -0.008131
# 3        0.017583  0.080177 -0.143573  0.058694 -0.157618 -0.081959 -0.018461
# 4        0.009526 -0.106335 -0.002508  0.106857 -0.078310 -0.008168  0.078693
# 5       -0.081212  0.123279 -0.161337  0.129052 -0.124283 -0.043053 -0.050881
# 6        0.018600  0.073331  0.176092  0.037669  0.094362  0.069743 -0.007507
# 7       -0.010809 -0.073932 -0.081632 -0.113499 -0.098633 -0.006557 -0.160446
# 8       -0.071186  0.080639 -0.007661  0.064091 -0.131240 -0.057647 -0.034124
# 9       -0.035664 -0.192844  0.013681  0.047777 -0.027666 -0.156628 -0.140069
# 10      -0.022427  0.038716  0.001853  0.024607 -0.128152 -0.159184  0.007326
# ...

# %%
ncols = 100
df = pd.DataFrame([
list(row)[:ncols] + [np.nan] * max(0, len(row) - ncols)
for row in c_vec
if np.ndim(row) == 1
])
df

# %%
len(text)
# Out:
# 802970

# %%
len(del_list)

# %%
pred=clf.predict(np.array(df))

# %%
len(pred)

# %%
for i in del_list:
    text = text.drop(i, axis=0)

# %%
text = text.drop(len(text), axis=0)

# %%
len(text)

# %%
len(df)

# %%
cpd
# Out:
#          Unnamed: 0        date      date.1  RT  Favo  \
# 0                 0  2016-01-01  2016-01-01   0     0
# 1                 2  2016-01-01  2016-01-01   1     2
# 2                 3  2016-01-01  2016-01-01   0     0
# 3                 4  2016-01-01  2016-01-01   0     0
# 4                 5  2016-01-01  2016-01-01   0     0
# 5                 6  2016-01-01  2016-01-01   0     0
# 6                 8  2016-01-01  2016-01-01   0     0
# 7                 9  2016-01-01  2016-01-01   0     0
# 8                11  2016-01-01  2016-01-01   0     0
# 9                12  2016-01-01  2016-01-01   0     0
# 10               14  2016-01-01  2016-01-01   0     1
# 11               17  2016-01-01  2016-01-01   0     0
# 12               18  2016-01-01  2016-01-01   0     0
# 13               20  2016-01-01  2016-01-01   0     0
# 14               21  2016-01-01  2016-01-01   0     1
# 15               22  2016-01-01  2016-01-01   0     0
# ...

# %%
cpd=pd.concat([text, df], axis=1)

# %%
ncp=cpd[cpd.iloc[:,90]<10]

# %%
len(cpd.drop(cpd[cpd.iloc[:,90]>10],axis=1))
# Out:
# 802970

# %%
ncp=ncp.reset_index()

# %%
ncp.iloc[0,6]
# Out:
# '初期に肉の交流を行った場合はツイートに掲載の可能性交。 万個。 # darkcoin # onacoin # bitcoin # sexcoin # dogecoin # litecoin'

# %%
a=cpd.iloc[:,107]
cpd=pd.concat([cpd.iloc[:,0:4], pd.DataFrame(a)], axis=1)

# %%
pred=clf.predict(np.array(ncp.iloc[:,10:110]))

# %%
cpd
# Out:
#                date  RT  Favo  \
# 0        2016-01-01   0     0
# 1        2016-01-01   1     2
# 2        2016-01-01   0     0
# 3        2016-01-01   0     0
# 4        2016-01-01   0     0
# 5        2016-01-01   0     0
# 6        2016-01-01   0     0
# 7        2016-01-01   0     0
# 8        2016-01-01   0     0
# 9        2016-01-01   0     0
# 10       2016-01-01   0     1
# 11       2016-01-01   0     0
# 12       2016-01-01   0     0
# 13       2016-01-01   0     0
# 14       2016-01-01   0     1
# 15       2016-01-01   0     0
# 16       2016-01-01   0     0
# 17       2016-01-01   0     0
# 18       2016-01-01   0     0
# 19       2016-01-01   0     0
# 20       2016-01-01   0     0
# 21       2016-01-01   0     0
# 22       2016-01-01   0     1
# 23       2016-01-01   0     1
# 24       2016-01-01   0     0
# 25       2016-01-01   0     0
# 26       2016-01-01   0     0
# 27       2016-01-01   0     0
# 28       2016-01-01   0     0
# 29       2016-01-01   0     1
# ...

# %%
cpd=pd.concat([ncp, pd.DataFrame(pred)], axis=1)

# %%
len(cpd)
# Out:
# 1038294

# %%
cpd=pd.concat([cpd.iloc[:,1:6], pd.DataFrame(pred)], axis=1)

# %%
cpd=cpd.drop('index',axis=1)

# %%
cpd=cpd.drop('Unnamed: 0',axis=1)
cpd=cpd.drop('date.1',axis=1)

# %%
#cpd.to_csv('w2v-svm-PN.csv')
cpd.to_csv('w2v-svm-PN-jyuuhuku.csv')

# %%
for i in range(0,len(cpd['date'])):
    cpd.at[i,'date']=cpd.at[i,'date'][:10]

# %%
days.index=pd.to_datetime(days['day'])

# %%
cpd.index=pd.to_datetime(cpd['date'])

# %%
for i in range(len(days['day'])):
    days.loc[i,'PN']=sum(cpd.loc[days.loc[i,'day']==cpd['date'],'PN'])/len(cpd.loc[days.loc[i,'day']==cpd['date'],'PN'])

# %%
cpd= cpd.rename(columns={0: 'PN'})

# %%
days.index=range(len(days))

# %%
cpd.loc[days.loc[1,'day']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-4ada0177da3d> in <module>()
# ----> 1 cpd.loc[days.loc[1,'day']]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1365             except (KeyError, IndexError):
#    1366                 pass
# -> 1367             return self._getitem_tuple(key)
#    1368         else:
#    1369             # we by definition only have the 0th axis
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     856     def _getitem_tuple(self, tup):
#     857         try:
# --> 858             return self._getitem_lowerdim(tup)
#     859         except IndexingError:
#     860             pass
#
# ...

# %%
sum(cpd.loc[days.loc[1,'day']==cpd['date'],'PN'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-2a910aba58a9> in <module>()
# ----> 1 sum(cpd.loc[days.loc[1,'day']==cpd['date'],'PN'])
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1365             except (KeyError, IndexError):
#    1366                 pass
# -> 1367             return self._getitem_tuple(key)
#    1368         else:
#    1369             # we by definition only have the 0th axis
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     856     def _getitem_tuple(self, tup):
#     857         try:
# --> 858             return self._getitem_lowerdim(tup)
#     859         except IndexingError:
#     860             pass
#
# ...

# %%
days
# Out:
#             day        PN
# 0    2016-01-01  2.000000
# 1    2016-01-02  2.051282
# 2    2016-01-03  2.021505
# 3    2016-01-04  1.982759
# 4    2016-01-05  1.963964
# 5    2016-01-06  2.047945
# 6    2016-01-07  2.126126
# 7    2016-01-08  1.948718
# 8    2016-01-09  1.942029
# 9    2016-01-10  1.892308
# 10   2016-01-11  2.101266
# 11   2016-01-12  2.065789
# 12   2016-01-13  1.852174
# 13   2016-01-14  2.025862
# 14   2016-01-15  2.028249
# 15   2016-01-16  1.889571
# 16   2016-01-17  2.112903
# 17   2016-01-18  2.125000
# 18   2016-01-19  1.935780
# 19   2016-01-20  1.958042
# 20   2016-01-21  1.908497
# 21   2016-01-22  1.961538
# 22   2016-01-23  2.097561
# 23   2016-01-24  2.010417
# 24   2016-01-25  1.962121
# 25   2016-01-26  2.008850
# 26   2016-01-27  1.989474
# 27   2016-01-28  2.038835
# 28   2016-01-29  2.056338
# 29   2016-01-30  1.961538
# ..          ...       ...
# 853  2018-05-03  2.116631
# 854  2018-05-04  2.170416
# 855  2018-05-05  2.111620
# ...

# %%
cpd=cpd.sort_index()

# %%
cpd=cpd.drop_duplicates()

# %%
days['PN']=-1

# %%
days.to_csv('w2v-svm-PN-jyuuhuku-sin.csv')

# %%
cpd = cpd.rename(columns={0: 'PN'})

# %%
cpd.loc[4,'PN']+1
# Out:
# 4

# %%
days=pd.read_csv("del-duplicate-newdata")

# %%
days=days.drop('Unnamed: 0',axis=1)
days=days.drop('sum',axis=1)

# %%
days
# Out:
#             day        PN
# 0    2016-01-01  2.000000
# 1    2016-01-02  2.051282
# 2    2016-01-03  2.021505
# 3    2016-01-04  1.982759
# 4    2016-01-05  1.963964
# 5    2016-01-06  2.047945
# 6    2016-01-07  2.126126
# 7    2016-01-08  1.948718
# 8    2016-01-09  1.942029
# 9    2016-01-10  1.892308
# 10   2016-01-11  2.101266
# 11   2016-01-12  2.065789
# 12   2016-01-13  1.852174
# 13   2016-01-14  2.025862
# 14   2016-01-15  2.028249
# 15   2016-01-16  1.889571
# 16   2016-01-17  2.112903
# 17   2016-01-18  2.125000
# 18   2016-01-19  1.935780
# 19   2016-01-20  1.958042
# 20   2016-01-21  1.908497
# 21   2016-01-22  1.961538
# 22   2016-01-23  2.097561
# 23   2016-01-24  2.010417
# 24   2016-01-25  1.962121
# 25   2016-01-26  2.008850
# 26   2016-01-27  1.989474
# 27   2016-01-28  2.038835
# 28   2016-01-29  2.056338
# 29   2016-01-30  1.961538
# ..          ...       ...
# 853  2018-05-03  2.116631
# 854  2018-05-04  2.170416
# 855  2018-05-05  2.111620
# ...
